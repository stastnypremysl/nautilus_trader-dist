# %%
from nautilus_trader.backtest.node import BacktestDataConfig
from nautilus_trader.backtest.node import BacktestEngineConfig
from nautilus_trader.backtest.node import BacktestNode
from nautilus_trader.backtest.node import BacktestRunConfig
from nautilus_trader.backtest.node import BacktestVenueConfig
from nautilus_trader.config import ImportableStrategyConfig
from nautilus_trader.config import LoggingConfig
from nautilus_trader.model import Quantity
from nautilus_trader.model import QuoteTick
from nautilus_trader.persistence.catalog import ParquetDataCatalog
from nautilus_trader.core.rust.model import TriggerType, TimeInForce
from nautilus_trader.model import TradeTick
from nautilus_trader.model import InstrumentId

# %%
catalog = ParquetDataCatalog("/home/p/p-dev/nautilus/catalog")
instrument_id = InstrumentId.from_str("APTUSDT-PERP.BINANCE")

# %%
venue = BacktestVenueConfig(
    name="BINANCE",
    oms_type="NETTING",
    account_type="MARGIN",
    base_currency="USDT",
    starting_balances=["100000 USDT"],
    default_leverage=10
)

# %%
data = BacktestDataConfig(
    catalog_path=str(catalog.path),
    data_cls=TradeTick,
    instrument_ids=[instrument_id],
    start_time="2024-12-10",
    end_time="2025-01-10"
)

# %%
engine = BacktestEngineConfig(
    strategies=[
        ImportableStrategyConfig(
            strategy_path="__main__:MACDStrategy",
            config_path="__main__:MACDConfig",
            config={
              "instrument_id": instrument_id,
              "fast_period": 12,
              "slow_period": 26,
            },
        )
    ],
    logging=LoggingConfig(log_level="INFO"),
)

# %%
from nautilus_trader.core.message import Event
from nautilus_trader.indicators.macd import MovingAverageConvergenceDivergence
from nautilus_trader.model import InstrumentId
from nautilus_trader.model import Position
from nautilus_trader.model.enums import PositionSide, OrderSide, PriceType, TrailingOffsetType
from nautilus_trader.core.rust.common import LogColor
from nautilus_trader.model.events import PositionOpened, PositionChanged, OrderFilled
from nautilus_trader.trading.strategy import Strategy
from nautilus_trader.trading.strategy import StrategyConfig



class MACDConfig(StrategyConfig):
    instrument_id: InstrumentId
    fast_period: int = 12
    slow_period: int = 26
    trade_size: int = 10000
    entry_threshold: float = 0.00010


class MACDStrategy(Strategy):
    def __init__(self, config: MACDConfig):
        super().__init__(config=config)
        self.log.info("Initialization of MACDStrategy")
        # Our "trading signal"
        self.macd = MovingAverageConvergenceDivergence(
            fast_period=config.fast_period, slow_period=config.slow_period, price_type=PriceType.MID
        )

        # Convenience
        self.position: Position | None = None

    
    def on_start(self):
        self.log.info("Start of MACDStrategy")
        
        self.instrument = self.cache.instrument(self.config.instrument_id)
        self.account = self.portfolio.account(self.instrument.venue)
        self.trade_size = self.instrument.make_qty(self.config.trade_size)

        self.subscribe_trade_ticks(instrument_id=self.config.instrument_id)


    def on_stop(self):
        self.log.info("Stop of MACDStrategy")
        self.close_all_positions(self.config.instrument_id)
        self.unsubscribe_trade_ticks(instrument_id=self.config.instrument_id)                
        
        

    def on_trade_tick(self, tick: TradeTick):
        # You can register indicators to receive quote tick updates automatically,
        # here we manually update the indicator to demonstrate the flexibility available
        self.macd.handle_trade_tick(tick)

        if not self.macd.initialized:
            return  # Wait for indicator to warm up

        # self._log.info(f"{self.macd.value=}:%5d")
        self.check_for_entry(tick)

    
    def check_for_entry(self, tick: TradeTick):
        # If MACD line is above our entry threshold, we should be LONG
        if self.macd.value > self.config.entry_threshold:
            if self.position and self.position.side == PositionSide.LONG:
                return  # Already LONG

            order = self.order_factory.market(
                instrument_id=self.config.instrument_id,
                order_side=OrderSide.BUY,
                quantity=self.trade_size,
            )
            self.position_open_price = tick.price
            self.submit_order(order)
            
        # If MACD line is below our entry threshold, we should be SHORT
        elif self.macd.value < -self.config.entry_threshold:
            if self.position and self.position.side == PositionSide.SHORT:
                return  # Already SHORT
            
            order = self.order_factory.market(
                instrument_id=self.config.instrument_id,
                order_side=OrderSide.SELL,
                quantity=self.trade_size,
            )
            self.position_open_price = tick.price
            self.submit_order(order)

    
    def on_position_opened(self, event: PositionOpened):
        self.position = self.cache.position(event.position_id)

        
        if self.position.side == PositionSide.LONG:
            inverse_order_side = OrderSide.SELL
        else:
            inverse_order_side = OrderSide.BUY

        
        trailing_stop_offset = self.instrument.make_price(
            self.position_open_price * 0.01 / 5
        )
                
        quantity = self.instrument.make_qty(
            self.config.trade_size
        )


        self.__trailing_stop_market_order = self.order_factory.trailing_stop_market(
            self.config.instrument_id,
            inverse_order_side,
            quantity,
            trailing_stop_offset,
            trailing_offset_type=TrailingOffsetType.PRICE,
            trigger_price=None,
            trigger_type=TriggerType.LAST_PRICE,
            reduce_only=True,
            tags=["TRAILING_STOP"],
            time_in_force=TimeInForce.GTC,
            expire_time=None,
            quote_quantity=False,
            emulation_trigger=TriggerType.NO_TRIGGER,
            trigger_instrument_id=None,
            exec_algorithm_id=None,
            exec_algorithm_params=None
        )
        self.submit_order(self.__trailing_stop_market_order)


    def on_order_filled(self, event: OrderFilled):
        self.log.info(f"Filled qty {event.last_qty}", LogColor.BLUE)

    def on_dispose(self):
        pass  # Do nothing else

# %%
config = BacktestRunConfig(
    engine=engine,
    venues=[venue],
    data=[data],
    chunk_size=1024*32
)

# %%
from nautilus_trader.backtest.results import BacktestResult


node = BacktestNode(configs=[config])

results: list[BacktestResult] = node.run()
# Out:
# 2025-04-20T18:48:02.922104973Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:02.922131205Z [INFO] BACKTESTER-001.BacktestEngine:  NAUTILUS TRADER - Automated Algorithmic Trading Platform
# 2025-04-20T18:48:02.922132956Z [INFO] BACKTESTER-001.BacktestEngine:  by Nautech Systems Pty Ltd.
# 2025-04-20T18:48:02.922133998Z [INFO] BACKTESTER-001.BacktestEngine:  Copyright (C) 2015-2025. All rights reserved.
# 2025-04-20T18:48:02.922134723Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:02.922135849Z [INFO] BACKTESTER-001.BacktestEngine:
# 2025-04-20T18:48:02.922136498Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣴⣶⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# 2025-04-20T18:48:02.922137567Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣾⣿⣿⣿⠀⢸⣿⣿⣿⣿⣶⣶⣤⣀⠀⠀⠀⠀⠀
# 2025-04-20T18:48:02.922138960Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⢀⣴⡇⢀⣾⣿⣿⣿⣿⣿⠀⣾⣿⣿⣿⣿⣿⣿⣿⠿⠓⠀⠀⠀���
# 2025-04-20T18:48:02.922140079Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⣰⣿⣿⡀⢸⣿⣿⣿⣿⣿⣿⠀⣿⣿⣿⣿⣿⣿⠟⠁⣠⣄⠀⠀⠀⠀
# 2025-04-20T18:48:02.922141022Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⢠⣿⣿⣿⣇⠀⢿⣿⣿⣿⣿⣿⠀⢻⣿⣿⣿⡿⢃⣠⣾⣿⣿⣧⡀⠀⠀
# 2025-04-20T18:48:02.922142047Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠠⣾⣿⣿⣿⣿⣿⣧⠈⠋⢀⣴⣧⠀⣿⡏⢠⡀⢸⣿⣿⣿⣿⣿⣿⣿⡇⠀
# 2025-04-20T18:48:02.922142960Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⣀⠙⢿⣿⣿⣿⣿⣿⠇⢠⣿⣿⣿⡄⠹⠃⠼⠃⠈⠉⠛⠛⠛⠛⠛⠻⠇⠀
# 2025-04-20T18:48:02.922143681Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⢸⡟⢠⣤⠉⠛⠿⢿⣿⠀⢸⣿⡿⠋⣠⣤⣄⠀⣾⣿⣿⣶⣶⣶⣦⡄⠀⠀⠀
# 2025-04-20T18:48:02.922144583Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠸⠀⣾⠏⣸⣷⠂⣠⣤⠀⠘��⣴⣾⣿⣿⣿⡆⠘⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀
# 2025-04-20T18:48:02.922145609Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠛⠀⣿⡟⠀⢻⣿⡄⠸⣿⣿⣿⣿⣿⣿⣿⡀⠘⣿⣿⣿⣿⠟⠀⠀⠀⠀
# 2025-04-20T18:48:02.922146889Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⣿⠇⠀⠀⢻⡿⠀⠈⠻⣿⣿⣿⣿⣿⡇⠀⢹⣿⠿⠋⠀⠀⠀⠀⠀
# 2025-04-20T18:48:02.922147624Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⠋⠀⠀⠀⡘⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠁⠀⠀⠀⠀⠀⠀⠀
# 2025-04-20T18:48:02.922148529Z [INFO] BACKTESTER-001.BacktestEngine:
# 2025-04-20T18:48:02.922149161Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:02.922150133Z [INFO] BACKTESTER-001.BacktestEngine:  SYSTEM SPECIFICATION
# 2025-04-20T18:48:02.922150882Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:02.922153455Z [INFO] BACKTESTER-001.BacktestEngine: CPU architecture: Intel(R) Xeon(R) CPU E5-2440 0 @ 2.40GHz
# 2025-04-20T18:48:02.922157260Z [INFO] BACKTESTER-001.BacktestEngine: CPU(s): 24 @ 1197 Mhz
# 2025-04-20T18:48:02.922159489Z [INFO] BACKTESTER-001.BacktestEngine: OS: kernel-5.15.88-gentoo Linux (Gentoo 2.17)
# 2025-04-20T18:48:03.412429626Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.412451007Z [INFO] BACKTESTER-001.BacktestEngine:  MEMORY USAGE
# 2025-04-20T18:48:03.412452761Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.412478699Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Total: 94.34 GiB
# 2025-04-20T18:48:03.412481716Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Used: 10.08 GiB (10.69%)
# 2025-04-20T18:48:03.412483831Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Avail: 84.26 GiB (89.31%)
# 2025-04-20T18:48:03.412488452Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Total: 128.00 GiB
# 2025-04-20T18:48:03.412495726Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Used: 1.41 GiB (1.10%)
# 2025-04-20T18:48:03.412499870Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Avail: 126.59 GiB (98.90%)
# 2025-04-20T18:48:03.420870187Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.420881644Z [INFO] BACKTESTER-001.BacktestEngine:  IDENTIFIERS
# 2025-04-20T18:48:03.420882843Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.420886325Z [INFO] BACKTESTER-001.BacktestEngine: trader_id: BACKTESTER-001
# 2025-04-20T18:48:03.420887681Z [INFO] BACKTESTER-001.BacktestEngine: machine_id: alpha
# 2025-04-20T18:48:03.420890976Z [INFO] BACKTESTER-001.BacktestEngine: instance_id: a157e2a5-b995-44cf-9c92-10de200aa1b5
# 2025-04-20T18:48:03.420892820Z [INFO] BACKTESTER-001.BacktestEngine: PID: 789040
# 2025-04-20T18:48:03.420893582Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.420894397Z [INFO] BACKTESTER-001.BacktestEngine:  VERSIONING
# 2025-04-20T18:48:03.420895153Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.420979847Z [INFO] BACKTESTER-001.BacktestEngine: nautilus_trader: 1.217.2
# 2025-04-20T18:48:03.420996293Z [INFO] BACKTESTER-001.BacktestEngine: python: 3.12.9
# 2025-04-20T18:48:03.421007446Z [INFO] BACKTESTER-001.BacktestEngine: numpy: 2.2.5
# 2025-04-20T18:48:03.421016952Z [INFO] BACKTESTER-001.BacktestEngine: pandas: 2.2.3
# 2025-04-20T18:48:03.421026873Z [INFO] BACKTESTER-001.BacktestEngine: msgspec: 0.19.0
# 2025-04-20T18:48:03.421035844Z [INFO] BACKTESTER-001.BacktestEngine: pyarrow: 19.0.1
# 2025-04-20T18:48:03.421043639Z [INFO] BACKTESTER-001.BacktestEngine: pytz: 2025.2
# 2025-04-20T18:48:03.421051314Z [INFO] BACKTESTER-001.BacktestEngine: uvloop: 0.21.0
# 2025-04-20T18:48:03.421052333Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-20T18:48:03.433330323Z [INFO] BACKTESTER-001.BacktestEngine: Building system kernel
# 2025-04-20T18:48:03.433454903Z [INFO] BACKTESTER-001.MessageBus: config.database=None
# 2025-04-20T18:48:03.433468342Z [INFO] BACKTESTER-001.MessageBus: config.encoding='msgpack'
# 2025-04-20T18:48:03.433472772Z [INFO] BACKTESTER-001.MessageBus: config.timestamps_as_iso8601=False
# 2025-04-20T18:48:03.433475756Z [INFO] BACKTESTER-001.MessageBus: config.buffer_interval_ms=None
# 2025-04-20T18:48:03.433478663Z [INFO] BACKTESTER-001.MessageBus: config.autotrim_mins=None
# 2025-04-20T18:48:03.433481419Z [INFO] BACKTESTER-001.MessageBus: config.use_trader_prefix=True
# 2025-04-20T18:48:03.433483949Z [INFO] BACKTESTER-001.MessageBus: config.use_trader_id=True
# 2025-04-20T18:48:03.433486328Z [INFO] BACKTESTER-001.MessageBus: config.use_instance_id=False
# 2025-04-20T18:48:03.433522477Z [INFO] BACKTESTER-001.MessageBus: config.streams_prefix='stream'
# 2025-04-20T18:48:03.433527282Z [INFO] BACKTESTER-001.MessageBus: config.types_filter=None
# 2025-04-20T18:48:03.434150738Z [INFO] BACKTESTER-001.Cache: READY
# 2025-04-20T18:48:03.438646290Z [INFO] BACKTESTER-001.DataEngine: READY
# 2025-04-20T18:48:03.439351107Z [INFO] BACKTESTER-001.RiskEngine: READY
# 2025-04-20T18:48:03.439633612Z [INFO] BACKTESTER-001.RiskEngine: TradingState is ACTIVE
# 2025-04-20T18:48:03.439966030Z [INFO] BACKTESTER-001.Throttler-ORDER_SUBMIT_THROTTLER: READY
# 2025-04-20T18:48:03.440079303Z [INFO] BACKTESTER-001.RiskEngine: Set MAX_ORDER_SUBMIT_RATE: 100/00:00:01
# 2025-04-20T18:48:03.440238395Z [INFO] BACKTESTER-001.Throttler-ORDER_MODIFY_THROTTLER: READY
# 2025-04-20T18:48:03.440304325Z [INFO] BACKTESTER-001.RiskEngine: Set MAX_ORDER_MODIFY_RATE: 100/00:00:01
# 2025-04-20T18:48:03.440621262Z [INFO] BACKTESTER-001.ExecEngine: READY
# 2025-04-20T18:48:03.440994236Z [INFO] BACKTESTER-001.ExecEngine: config.snapshot_orders=False
# 2025-04-20T18:48:03.441012760Z [INFO] BACKTESTER-001.ExecEngine: config.snapshot_positions=False
# 2025-04-20T18:48:03.441019560Z [INFO] BACKTESTER-001.ExecEngine: config.snapshot_positions_interval_secs=None
# 2025-04-20T18:48:03.441145192Z [INFO] BACKTESTER-001.Cache: Cached 0 general objects from database
# 2025-04-20T18:48:03.441163526Z [INFO] BACKTESTER-001.Cache: Cached 0 currencies from database
# 2025-04-20T18:48:03.441170054Z [INFO] BACKTESTER-001.Cache: Cached 0 instruments from database
# 2025-04-20T18:48:03.441176236Z [INFO] BACKTESTER-001.Cache: Cached 0 accounts from database
# 2025-04-20T18:48:03.441182561Z [INFO] BACKTESTER-001.Cache: Cached 0 orders from database
# 2025-04-20T18:48:03.441189013Z [INFO] BACKTESTER-001.Cache: Cached 0 order lists from database
# 2025-04-20T18:48:03.441194503Z [INFO] BACKTESTER-001.Cache: Cached 0 positions from database
# 2025-04-20T18:48:03.441250780Z [INFO] BACKTESTER-001.Cache: Checking data integrity
# 2025-04-20T18:48:03.441283611Z [INFO] BACKTESTER-001.Cache: Integrity check passed in 23μs
# 2025-04-20T18:48:03.441325855Z [INFO] BACKTESTER-001.ExecEngine: Loaded cache in 0ms
# 2025-04-20T18:48:03.441494476Z [INFO] BACKTESTER-001.OrderEmulator: READY
# 2025-04-20T18:48:03.441989705Z [INFO] BACKTESTER-001.BACKTESTER-001: READY
# 2025-04-20T18:48:03.444160278Z [INFO] BACKTESTER-001.MACDStrategy: Initialization of MACDStrategy
# 2025-04-20T18:48:03.444380218Z [INFO] BACKTESTER-001.MACDStrategy: READY
# 2025-04-20T18:48:03.444918736Z [INFO] BACKTESTER-001.ExecEngine: Registered OMS.UNSPECIFIED for Strategy MACDStrategy-000
# 2025-04-20T18:48:03.444945927Z [INFO] BACKTESTER-001.BACKTESTER-001: Registered Strategy MACDStrategy-000
# 2025-04-20T18:48:03.445016873Z [INFO] BACKTESTER-001.BacktestEngine: Initialized in 1325ms
# 2025-04-20T18:48:03.457076584Z [INFO] BACKTESTER-001.SimulatedExchange(BINANCE): OmsType=NETTING
# 2025-04-20T18:48:03.457234954Z [INFO] BACKTESTER-001.ExecClient-BINANCE: READY
# 2025-04-20T18:48:03.457633706Z [INFO] BACKTESTER-001.SimulatedExchange(BINANCE): Registered ExecutionClient-BINANCE
# 2025-04-20T18:48:03.457667373Z [INFO] BACKTESTER-001.ExecEngine: Registered ExecutionClient-BINANCE
# 2025-04-20T18:48:03.457686191Z [INFO] BACKTESTER-001.BacktestEngine: Added SimulatedExchange(id=BINANCE, oms_type=NETTING, account_type=MARGIN)
# 2025-04-20T18:48:03.515882186Z [INFO] BACKTESTER-001.DataClient-BINANCE: READY
# 2025-04-20T18:48:03.515992161Z [INFO] BACKTESTER-001.DataEngine: Registered BINANCE
# 2025-04-20T18:48:03.516688250Z [INFO] BACKTESTER-001.SimulatedExchange(BINANCE): Added instrument APTUSDT-PERP.BINANCE and created matching engine
# 2025-04-20T18:48:03.516708585Z [INFO] BACKTESTER-001.BacktestEngine: Added APTUSDT-PERP.BINANCE Instrument
# 2025-04-20T18:48:03.938098068Z [INFO] BACKTESTER-001.BacktestEngine: Added 32_768 data elements
# 2025-04-20T18:48:03.939084097Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=True, balances=[AccountBalance(total=100_000.00000000 USDT, locked=0.00000000 USDT, free=100_000.00000000 USDT)], margins=[], event_id=17c7c983-1c40-48c0-96b0-cdd106d9a9a4)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: STARTING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataClient-BINANCE: Connecting...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataClient-BINANCE: Connected
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataClient-BINANCE: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataEngine: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.RiskEngine: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecClient-BINANCE: Connecting...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecClient-BINANCE: Connected
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecClient-BINANCE: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecEngine: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataEngine: Connecting all clients...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecEngine: Connecting all clients...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.OrderEmulator: No emulated orders to reactivate
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.OrderEmulator: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.Portfolio: Initialized 0 open orders
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.Portfolio: Initialized 0 open positions
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: self.config.oms_type=None
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: self.config.external_order_claims=None
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: self.config.manage_gtd_expiry=False
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: Set ClientOrderIdGenerator client_order_id count to 0
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: Set ClientOrderIdGenerator order_list_id count to 0
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: Start of MACDStrategy
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubscribeTradeTicks(instrument_id=APTUSDT-PERP.BINANCE, client_id=None, venue=BINANCE)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BACKTESTER-001: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine:  MEMORY USAGE
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Total: 94.34 GiB
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Used: 10.22 GiB (10.83%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Avail: 84.12 GiB (89.17%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Total: 128.00 GiB
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Used: 1.41 GiB (1.10%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Avail: 126.59 GiB (98.90%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine:  SimulatedVenue BINANCE
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: MarginAccount(id=BINANCE-001, type=MARGIN, base=USDT)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: -----------------------------------------------------------------
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Balances starting:
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: 100_000.00000000 USDT
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine:  BACKTEST RUN
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Run config ID:  43fbb9e565c95fefc1958e96631182980d4806eee7c8ceb95a3592b7ca8af086
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Run ID:         af30dbbb-d7fd-4a55-81a9-cabc1a12fae4
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Run started:    2025-04-20T18:48:03.938711000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Backtest start: 2024-12-10T00:00:04.998000000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Batch start:    2024-12-10T00:00:04.998000000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Batch end:      2024-12-10T00:20:05.689000000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: -----------------------------------------------------------------
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, side=SELL, type=MARKET, quantity=10_000.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(SELL 10_000.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-1, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_999.99403215 USDT, locked=0.00000000 USDT, free=99_999.99403215 USDT)], margins=[], event_id=235f525c-fd3d-42a7-b951-f00e1148b080)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, venue_order_id=BINANCE-1-001, account_id=BINANCE-001, trade_id=BINANCE-1-001, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=1.0, last_px=11.93570 USDT, commission=0.00596785 USDT, liquidity_side=TAKER, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: Filled qty 1.0
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-1.0
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.03043604 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000005-001-000-1, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-1.0, quantity=1.0, peak_qty=1.0, currency=USDT, avg_px_open=11.9357, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.00596785 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788805048000000, ts_last=1733788805048000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, side=BUY, type=TRAILING_STOP_MARKET, quantity=10_000.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': None, 'trigger_type': 'LAST_PRICE', 'trailing_offset': '0.02390', 'trailing_offset_type': 'PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TRAILING_STOP'])
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=TrailingStopMarketOrder(BUY 10_000.0 APTUSDT-PERP.BINANCE TRAILING_STOP_MARKET[LAST_PRICE] 0.02390-TRAILING_OFFSET[PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-2, venue_order_id=None, position_id=None, tags=['TRAILING_STOP']), position_id=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=0.03043604 USDT, free=99_940.29156391 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=0.03043604 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=268a3e64-71d0-43d6-8e12-f93cc0ecc507)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, venue_order_id=BINANCE-1-001, account_id=BINANCE-001, trade_id=BINANCE-1-002, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=9_999.0, last_px=11.93560 USDT, commission=59.67203220 USDT, liquidity_side=TAKER, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: Filled qty 9999.0
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-10000.0
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=304.35780000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000005-001-000-1, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-10000.0, quantity=10_000.0, peak_qty=10_000.0, currency=USDT, avg_px_open=11.93560001, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-59.67800005 USDT, unrealized_pnl=0.00010000 USDT, ts_opened=1733788805048000000, ts_last=1733788805048000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=394132ef-b241-4581-994e-285dd9970bbc)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=23c59834-7d68-4ab7-b7e3-071ecb1671a1)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95960, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=ef123bb0-832b-4ea2-b122-26e018fd8e09)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95930, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.089000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.089000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=c1cf6099-fecd-444a-a195-07897dc9eaa3)
# 2024-12-10T00:00:05.089000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95530, ts_event=1733788805089000000)
# 2024-12-10T00:00:05.312000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.312000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=6d3bd108-f9e4-4aaa-bfd7-6779cbcd4e0e)
# 2024-12-10T00:00:05.312000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95510, ts_event=1733788805312000000)
# 2024-12-10T00:00:05.353000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.353000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=f45add9b-913d-4430-b9e1-748035bd2937)
# 2024-12-10T00:00:05.353000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95490, ts_event=1733788805353000000)
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=be74f51c-3059-4f7c-a0e4-14f8401ecf9f)
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95470, ts_event=1733788805417000000)
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=b292a20f-b17d-4bd3-859c-eb2e26c3c023)
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95440, ts_event=1733788805417000000)
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=64bb6d6c-6f80-405e-a91b-faf75490d32c)
# 2024-12-10T00:00:05.417000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95430, ts_event=1733788805417000000)
# 2024-12-10T00:00:06.613000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.613000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=1c7f164a-a2c1-4b85-8ca0-529b056726e1)
# 2024-12-10T00:00:06.613000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95420, ts_event=1733788806613000000)
# 2024-12-10T00:00:06.623000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.623000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=51eb602d-1c0e-4405-b8b4-de3cb01a8a85)
# 2024-12-10T00:00:06.623000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95380, ts_event=1733788806623000000)
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=03a59065-be4c-4854-90d0-167141acbd4b)
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95370, ts_event=1733788806624000000)
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=8c87e580-8684-4a97-a092-44f77404c749)
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95330, ts_event=1733788806624000000)
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=593e44fc-fc3a-407a-862d-ba4187c6d584)
# 2024-12-10T00:00:06.624000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95310, ts_event=1733788806624000000)
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=3ce0b180-af54-4f74-9018-5e242bff34f9)
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95300, ts_event=1733788806794000000)
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=8aadc498-10cf-4c52-9226-51a37c233f58)
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95290, ts_event=1733788806794000000)
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=683cf450-807d-4c77-ba7e-e52a06a3ecb2)
# 2024-12-10T00:00:06.794000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95280, ts_event=1733788806794000000)
# 2024-12-10T00:00:06.863000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:06.863000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=4c1e131b-b028-461d-a82c-292198b15476)
# 2024-12-10T00:00:06.863000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95270, ts_event=1733788806863000000)
# 2024-12-10T00:00:07.322000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.322000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=dd8b9232-e91e-4258-aa25-bb17053cbd3f)
# 2024-12-10T00:00:07.322000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95260, ts_event=1733788807322000000)
# 2024-12-10T00:00:07.327000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.327000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=45a2d859-f97a-4bbb-bcbd-46ca1b5258f1)
# 2024-12-10T00:00:07.327000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95250, ts_event=1733788807327000000)
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=3f7fda37-f804-4d2b-8edc-e7d33d6756e1)
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95220, ts_event=1733788807444000000)
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=62b7a49b-2385-4143-a1af-002fc3a7ef02)
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95210, ts_event=1733788807444000000)
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=c5a14724-c583-4fe3-af69-1bb9b872dee1)
# 2024-12-10T00:00:07.444000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95200, ts_event=1733788807444000000)
# 2024-12-10T00:00:07.464000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.464000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=57f57af4-361e-4338-b869-d6d3eb852f56)
# 2024-12-10T00:00:07.464000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95190, ts_event=1733788807464000000)
# 2024-12-10T00:00:07.464000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.464000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=b71b1d40-b439-4c32-adb1-2d860364c9f5)
# 2024-12-10T00:00:07.464000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95180, ts_event=1733788807464000000)
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=1d7ca713-fe05-4495-8fa6-25802d83afe3)
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95140, ts_event=1733788807580000000)
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=8c6a6bec-912e-472d-920d-a04331c044dc)
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95120, ts_event=1733788807580000000)
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=366d3000-96fd-4bbe-b8fe-a646d1203bcd)
# 2024-12-10T00:00:07.580000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95110, ts_event=1733788807580000000)
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=9d67346a-6ab9-4452-8df3-90214702aa24)
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95080, ts_event=1733788807596000000)
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99_940.32199995 USDT, locked=304.35780000 USDT, free=99_635.96419995 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=304.35780000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=f8338a5e-8e0d-436f-8a50-c3a5bef1508f)
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderUpdated(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, quantity=10_000.0, price=None, trigger_price=11.95070, ts_event=1733788807596000000)
# 2024-12-10T00:00:07.596000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# ...
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=98_228.97430392 USDT, locked=423.20690322 USDT, free=97_805.76740070 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=423.20690322 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=498cb69d-53fb-47aa-b82c-f3c018a312a2)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000015-001-000-27, venue_order_id=BINANCE-1-027, account_id=BINANCE-001, trade_id=BINANCE-1-506, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=TRAILING_STOP_MARKET, last_qty=125.8, last_px=11.90910 USDT, commission=0.74908239 USDT, liquidity_side=TAKER, ts_event=1733788834272000000)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: Filled qty 125.8
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-14059.9
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=427.02770460 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000033-001-000-53, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-14059.9, quantity=14_059.9, peak_qty=14_059.9, currency=USDT, avg_px_open=11.910550000355737, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-83.73057164 USDT, unrealized_pnl=20.38686000 USDT, ts_opened=1733788833305000000, ts_last=1733788834272000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=98_228.22522153 USDT, locked=427.02770460 USDT, free=97_801.19751693 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=427.02770460 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=7bdeea26-8c5e-4203-9e2f-0ad4565900a6)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000012-001-000-23, venue_order_id=BINANCE-1-023, account_id=BINANCE-001, trade_id=BINANCE-1-507, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=TRAILING_STOP_MARKET, last_qty=125.8, last_px=11.90910 USDT, commission=0.74908239 USDT, liquidity_side=TAKER, ts_event=1733788834272000000)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: Filled qty 125.8
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-14185.7
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=430.84488862 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000033-001-000-53, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-14185.7, quantity=14_185.7, peak_qty=14_185.7, currency=USDT, avg_px_open=11.910537141628655, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-84.47965403 USDT, unrealized_pnl=20.38686000 USDT, ts_opened=1733788833305000000, ts_last=1733788834272000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=98_227.47613914 USDT, locked=430.84488862 USDT, free=97_796.63125052 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=430.84488862 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=04782a38-fb0b-464c-9268-4a7406d4be8a)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, venue_order_id=BINANCE-1-019, account_id=BINANCE-001, trade_id=BINANCE-1-508, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=TRAILING_STOP_MARKET, last_qty=125.8, last_px=11.90910 USDT, commission=0.74908239 USDT, liquidity_side=TAKER, ts_event=1733788834272000000)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: Filled qty 125.8
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-14311.5
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=434.66565791 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000033-001-000-53, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-14311.5, quantity=14_311.5, peak_qty=14_311.5, currency=USDT, avg_px_open=11.910524508961437, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-85.22873642 USDT, unrealized_pnl=20.38686000 USDT, ts_opened=1733788833305000000, ts_last=1733788834272000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=98_226.72705675 USDT, locked=434.66565791 USDT, free=97_792.06139884 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=434.66565791 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=0bdb19eb-ffb2-49db-887b-cc4b20cc042c)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, venue_order_id=BINANCE-1-015, account_id=BINANCE-001, trade_id=BINANCE-1-509, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=TRAILING_STOP_MARKET, last_qty=125.8, last_px=11.90910 USDT, commission=0.74908239 USDT, liquidity_side=TAKER, ts_event=1733788834272000000)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: Filled qty 125.8
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-14437.3
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=438.48642721 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000033-001-000-53, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-14437.3, quantity=14_437.3, peak_qty=14_437.3, currency=USDT, avg_px_open=11.910512096444737, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-85.97781881 USDT, unrealized_pnl=20.38686000 USDT, ts_opened=1733788833305000000, ts_last=1733788834272000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=98_225.97797436 USDT, locked=438.48642721 USDT, free=97_787.49154715 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=438.48642721 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=840dfdb1-34bf-4c52-9bea-bab7e660a050)
# 2024-12-10T00:00:34.272000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-5, venue_order_id=BINANCE-1-005, account_id=BINANCE-001, trade_id=BINANCE-1-510, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=TRAILING_STOP_MARKET, last_qty=125.8, last_px=11.90910 USDT, com
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 6
#       1 from nautilus_trader.backtest.results import BacktestResult
#       4 node = BacktestNode(configs=[config])
# ----> 6 results: list[BacktestResult] = node.run()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/node.py:214, in BacktestNode.run(self, raise_exception)
#     212 for config in self._configs:
#     213     try:
# --> 214         result = self._run(
#     215             run_config_id=config.id,
#     216             engine_config=config.engine,
#     217             venue_configs=config.venues,
#     218             data_configs=config.data,
#     219             chunk_size=config.chunk_size,
#     220             dispose_on_completion=config.dispose_on_completion,
#     221             start=config.start,
#     222             end=config.end,
#     223         )
#     224         results.append(result)
#     225     except Exception as e:
#     226         # Broad catch all prevents a single backtest run from halting
#     227         # the execution of the other backtests (such as a zero balance exception).
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/node.py:268, in BacktestNode._run(self, run_config_id, engine_config, venue_configs, data_configs, chunk_size, dispose_on_completion, start, end)
#     266 # Run backtest
#     267 if chunk_size is not None:
# --> 268     self._run_streaming(
#     269         run_config_id=run_config_id,
#     270         engine=engine,
#     271         data_configs=data_configs,
#     272         chunk_size=chunk_size,
#     273         start=start,
#     274         end=end,
#     275     )
#     276 else:
#     277     self._run_oneshot(
#     278         run_config_id=run_config_id,
#     279         engine=engine,
#    (...)    282         end=end,
#     283     )
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/node.py:413, in BacktestNode._run_streaming(self, run_config_id, engine, data_configs, chunk_size, start, end)
#     407 for chunk in session.to_query_result():
#     408     engine.add_data(
#     409         data=capsule_to_list(chunk),
#     410         validate=False,  # Cannot validate mixed type stream
#     411         sort=True,  # Already sorted from backend
#     412     )
# --> 413     engine.run(
#     414         start=start,
#     415         end=end,
#     416         run_config_id=run_config_id,
#     417         streaming=True,
#     418     )
#     419     engine.clear_data()
#     421 engine.end()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/engine.pyx:985, in nautilus_trader.backtest.engine.BacktestEngine.run()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/engine.pyx:1212, in nautilus_trader.backtest.engine.BacktestEngine._run()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/exchange.pyx:792, in nautilus_trader.backtest.exchange.SimulatedExchange.process_trade_tick()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:559, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine.process_trade_tick()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:1492, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine.iterate()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/matching_core.pyx:248, in nautilus_trader.execution.matching_core.MatchingCore.iterate()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/matching_core.pyx:285, in nautilus_trader.execution.matching_core.MatchingCore.match_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/matching_core.pyx:306, in nautilus_trader.execution.matching_core.MatchingCore.match_stop_market_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:1725, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine.fill_market_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:1758, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine.fill_market_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:1963, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine.apply_fills()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:2074, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine.fill_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/backtest/matching_engine.pyx:2590, in nautilus_trader.backtest.matching_engine.OrderMatchingEngine._generate_order_filled()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/common/component.pyx:2420, in nautilus_trader.common.component.MessageBus.send()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/engine.pyx:705, in nautilus_trader.execution.engine.ExecutionEngine.process()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/engine.pyx:717, in nautilus_trader.execution.engine.ExecutionEngine.process()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/engine.pyx:1025, in nautilus_trader.execution.engine.ExecutionEngine._handle_event()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/execution/engine.pyx:1151, in nautilus_trader.execution.engine.ExecutionEngine._apply_event_to_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/common/component.pyx:2640, in nautilus_trader.common.component.MessageBus.publish_c()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/portfolio/portfolio.pyx:432, in nautilus_trader.portfolio.portfolio.Portfolio.update_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/portfolio/portfolio.pyx:486, in nautilus_trader.portfolio.portfolio.Portfolio.update_order()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/accounting/manager.pyx:122, in nautilus_trader.accounting.manager.AccountsManager.update_balances()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/accounting/manager.pyx:501, in nautilus_trader.accounting.manager.AccountsManager._update_balance_single_currency()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/accounting/accounts/base.pyx:446, in nautilus_trader.accounting.accounts.base.Account.update_commissions()
#
# File ~/nautilus/venv/lib/python3.12/site-packages/nautilus_trader/model/objects.pyx:1252, in nautilus_trader.model.objects.Money.as_decimal()
#
# KeyboardInterrupt:

# %%
from nautilus_trader.backtest.engine import BacktestEngine
from nautilus_trader.model import Venue


engine: BacktestEngine = node.get_engine(config.id)

engine.trader.generate_order_fills_report()

# %%
engine.trader.generate_positions_report()

# %%
engine.trader.generate_account_report(Venue("BINANCE"))
