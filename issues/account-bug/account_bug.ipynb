# %%
from nautilus_trader.backtest.node import BacktestDataConfig
from nautilus_trader.backtest.node import BacktestEngineConfig
from nautilus_trader.backtest.node import BacktestNode
from nautilus_trader.backtest.node import BacktestRunConfig
from nautilus_trader.backtest.node import BacktestVenueConfig
from nautilus_trader.config import ImportableStrategyConfig
from nautilus_trader.config import LoggingConfig
from nautilus_trader.model import Quantity
from nautilus_trader.model import QuoteTick
from nautilus_trader.persistence.catalog import ParquetDataCatalog
from nautilus_trader.core.rust.model import TriggerType, TimeInForce
from nautilus_trader.model import TradeTick
from nautilus_trader.model import InstrumentId

# %%
catalog = ParquetDataCatalog("/home/p/p-dev/nautilus/catalog")
instrument_id = InstrumentId.from_str("APTUSDT-PERP.BINANCE")

# %%
venue = BacktestVenueConfig(
    name="BINANCE",
    oms_type="NETTING",
    account_type="MARGIN",
    base_currency="USDT",
    starting_balances=["100 USDT"],
    default_leverage=10
)

# %%
data = BacktestDataConfig(
    catalog_path=str(catalog.path),
    data_cls=TradeTick,
    instrument_ids=[instrument_id],
    start_time="2024-12-10",
    end_time="2025-01-10"
)

# %%
engine = BacktestEngineConfig(
    strategies=[
        ImportableStrategyConfig(
            strategy_path="__main__:MACDStrategy",
            config_path="__main__:MACDConfig",
            config={
              "instrument_id": instrument_id,
              "fast_period": 12,
              "slow_period": 26,
            },
        )
    ],
    logging=LoggingConfig(log_level="DEBUG"),
)

# %%
from nautilus_trader.core.message import Event
from nautilus_trader.indicators.macd import MovingAverageConvergenceDivergence
from nautilus_trader.model import InstrumentId
from nautilus_trader.model import Position
from nautilus_trader.model.enums import OrderSide
from nautilus_trader.model.enums import PositionSide
from nautilus_trader.model.enums import PriceType
from nautilus_trader.core.rust.common import LogColor
from nautilus_trader.model.events import PositionOpened, PositionChanged, OrderAccepted
from nautilus_trader.trading.strategy import Strategy
from nautilus_trader.trading.strategy import StrategyConfig



class MACDConfig(StrategyConfig):
    instrument_id: InstrumentId
    fast_period: int = 12
    slow_period: int = 26
    trade_size: int = 500
    entry_threshold: float = 0.00010


class MACDStrategy(Strategy):
    def __init__(self, config: MACDConfig):
        super().__init__(config=config)
        self.log.info("Initialization of MACDStrategy")
        # Our "trading signal"
        self.macd = MovingAverageConvergenceDivergence(
            fast_period=config.fast_period, slow_period=config.slow_period, price_type=PriceType.MID
        )

        # Convenience
        self.position: Position | None = None

    
    def on_start(self):
        self.log.info("Start of MACDStrategy")
        
        self.instrument = self.cache.instrument(self.config.instrument_id)
        self.account = self.portfolio.account(self.instrument.venue)
        self.trade_size = self.instrument.make_qty(self.config.trade_size)

        self.subscribe_trade_ticks(instrument_id=self.config.instrument_id)


    def on_stop(self):
        self.log.info("Stop of MACDStrategy")
        self.close_all_positions(self.config.instrument_id)
        self.unsubscribe_trade_ticks(instrument_id=self.config.instrument_id)

    
    def on_order_accepted(self, event: OrderAccepted):
        if self.__stop_loss_order is not None:
            if self.__stop_loss_order.client_order_id == event.client_order_id:
                self.log.info(f"After stop loss order accepted balances locked: " + 
                              f"{self.account.balances_locked()[self.account.base_currency].as_double()}", LogColor.MAGENTA)
                return

        if self.__take_profit_order is not None:
            if self.__take_profit_order.client_order_id == event.client_order_id:
                self.log.info(f"After take profit order accepted balances locked: " + 
                              f"{self.account.balances_locked()[self.account.base_currency].as_double()}", LogColor.MAGENTA)
                return

        self.log.info(f"After unidentified order accepted balances locked: " + 
            f"{self.account.balances_locked()[self.account.base_currency].as_double()}", LogColor.MAGENTA)
                
        
        

    def on_trade_tick(self, tick: TradeTick):
        # You can register indicators to receive quote tick updates automatically,
        # here we manually update the indicator to demonstrate the flexibility available
        self.macd.handle_trade_tick(tick)

        if not self.macd.initialized:
            return  # Wait for indicator to warm up

        # self._log.info(f"{self.macd.value=}:%5d")
        self.check_for_entry(tick)
        self.check_for_exit()


    def check_for_entry(self, tick: TradeTick):
        # If MACD line is above our entry threshold, we should be LONG
        if self.macd.value > self.config.entry_threshold:
            if self.position and self.position.side == PositionSide.LONG:
                return  # Already LONG

            order = self.order_factory.market(
                instrument_id=self.config.instrument_id,
                order_side=OrderSide.BUY,
                quantity=self.trade_size,
            )
            self.position_open_price = tick.price
            self.submit_order(order)
            
        # If MACD line is below our entry threshold, we should be SHORT
        elif self.macd.value < -self.config.entry_threshold:
            if self.position and self.position.side == PositionSide.SHORT:
                return  # Already SHORT
            
            order = self.order_factory.market(
                instrument_id=self.config.instrument_id,
                order_side=OrderSide.SELL,
                quantity=self.trade_size,
            )
            self.position_open_price = tick.price
            self.submit_order(order)
            

    def check_for_exit(self):
        # If MACD line is above zero then exit if we are SHORT
        if self.macd.value >= 0.0:
            if self.position and self.position.side == PositionSide.SHORT:
                self.close_position(self.position)
        # If MACD line is below zero then exit if we are LONG
        else:
            if self.position and self.position.side == PositionSide.LONG:
                self.close_position(self.position)

    
    def on_position_opened(self, event: PositionOpened):
        self.position = self.cache.position(event.position_id)

        if self.position.side == PositionSide.LONG:
            inverse_order_side = OrderSide.SELL

            take_profit_price = self.instrument.make_price(
                self.position_open_price * (1 + 0.05)
            )
            stop_loss_trigger_price = self.instrument.make_price(
                self.position_open_price * (1 - 0.05)
            )
        else:
            inverse_order_side = OrderSide.BUY

            take_profit_price = self.instrument.make_price(
                self.position_open_price * (1 - 0.05)
            )
            stop_loss_trigger_price = self.instrument.make_price(
                self.position_open_price * (1 + 0.05)
            )


        self.__stop_loss_order = self.order_factory.stop_market(
            self.config.instrument_id,
            inverse_order_side,
            event.quantity,
            trigger_price=stop_loss_trigger_price,
            trigger_type=TriggerType.LAST_PRICE,
            reduce_only=True,
            tags=["STOP"],
            time_in_force=TimeInForce.GTC,
            expire_time=None,
            quote_quantity=False,
            emulation_trigger=TriggerType.NO_TRIGGER,
            trigger_instrument_id=None,
            exec_algorithm_id=None,
            exec_algorithm_params=None
        )
        self.submit_order(self.__stop_loss_order)


        self.__take_profit_order = self.order_factory.limit(
            self.config.instrument_id,
            inverse_order_side,
            event.quantity,
            take_profit_price,
            reduce_only=True,
            post_only=False,
            tags=["TAKE_PROFIT"],
            time_in_force=TimeInForce.GTC,
            expire_time=None,
            quote_quantity=False,
            emulation_trigger=TriggerType.NO_TRIGGER,
            trigger_instrument_id=None,
            exec_algorithm_id=None,
            exec_algorithm_params=None,
            display_qty=None
        )
        self.submit_order(self.__take_profit_order)
    

    def on_dispose(self):
        pass  # Do nothing else

# %%
config = BacktestRunConfig(
    engine=engine,
    venues=[venue],
    data=[data],
    chunk_size=1024*32
)

# %%
from nautilus_trader.backtest.results import BacktestResult


node = BacktestNode(configs=[config])

results: list[BacktestResult] = node.run()
# Out:
# 2025-04-11T18:11:38.897055539Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.897080662Z [INFO] BACKTESTER-001.BacktestEngine:  NAUTILUS TRADER - Automated Algorithmic Trading Platform
# 2025-04-11T18:11:38.897084137Z [INFO] BACKTESTER-001.BacktestEngine:  by Nautech Systems Pty Ltd.
# 2025-04-11T18:11:38.897086185Z [INFO] BACKTESTER-001.BacktestEngine:  Copyright (C) 2015-2025. All rights reserved.
# 2025-04-11T18:11:38.897087558Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.897088902Z [INFO] BACKTESTER-001.BacktestEngine:
# 2025-04-11T18:11:38.897090018Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣴⣶⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# 2025-04-11T18:11:38.897092824Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣾⣿⣿⣿⠀⢸⣿⣿⣿⣿⣶⣶⣤⣀⠀⠀⠀⠀⠀
# 2025-04-11T18:11:38.897094234Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⢀⣴⡇⢀⣾⣿⣿⣿⣿⣿⠀⣾⣿⣿⣿⣿⣿⣿⣿⠿⠓⠀⠀⠀���
# 2025-04-11T18:11:38.897095544Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⣰⣿⣿⡀⢸⣿⣿⣿⣿⣿⣿⠀⣿⣿⣿⣿⣿⣿⠟⠁⣠⣄⠀⠀⠀⠀
# 2025-04-11T18:11:38.897096957Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⢠⣿⣿⣿⣇⠀⢿⣿⣿⣿⣿⣿⠀⢻⣿⣿⣿⡿⢃⣠⣾⣿⣿⣧⡀⠀⠀
# 2025-04-11T18:11:38.897098241Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠠⣾⣿⣿⣿⣿⣿⣧⠈⠋⢀⣴⣧⠀⣿⡏⢠⡀⢸⣿⣿⣿⣿⣿⣿⣿⡇⠀
# 2025-04-11T18:11:38.897100332Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⣀⠙⢿⣿⣿⣿⣿⣿⠇⢠⣿⣿⣿⡄⠹⠃⠼⠃⠈⠉⠛⠛⠛⠛⠛⠻⠇⠀
# 2025-04-11T18:11:38.897101558Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⢸⡟⢠⣤⠉⠛⠿⢿⣿⠀⢸⣿⡿⠋⣠⣤⣄⠀⣾⣿⣿⣶⣶⣶⣦⡄⠀⠀⠀
# 2025-04-11T18:11:38.897103186Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠸⠀⣾⠏⣸⣷⠂⣠⣤⠀⠘��⣴⣾⣿⣿⣿⡆⠘⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀
# 2025-04-11T18:11:38.897105635Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠛⠀⣿⡟⠀⢻⣿⡄⠸⣿⣿⣿⣿⣿⣿⣿⡀⠘⣿⣿⣿⣿⠟⠀⠀⠀⠀
# 2025-04-11T18:11:38.897107222Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⣿⠇⠀⠀⢻⡿⠀⠈⠻⣿⣿⣿⣿⣿⡇⠀⢹⣿⠿⠋⠀⠀⠀⠀⠀
# 2025-04-11T18:11:38.897108809Z [INFO] BACKTESTER-001.BacktestEngine: ⠀⠀⠀⠀⠀⠀⠋⠀⠀⠀⡘⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠁⠀⠀⠀⠀⠀⠀⠀
# 2025-04-11T18:11:38.897111161Z [INFO] BACKTESTER-001.BacktestEngine:
# 2025-04-11T18:11:38.897112150Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.897113570Z [INFO] BACKTESTER-001.BacktestEngine:  SYSTEM SPECIFICATION
# 2025-04-11T18:11:38.897114609Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.897119484Z [INFO] BACKTESTER-001.BacktestEngine: CPU architecture: Intel(R) Xeon(R) CPU E5-2440 0 @ 2.40GHz
# 2025-04-11T18:11:38.897123377Z [INFO] BACKTESTER-001.BacktestEngine: CPU(s): 24 @ 1197 Mhz
# 2025-04-11T18:11:38.897127443Z [INFO] BACKTESTER-001.BacktestEngine: OS: kernel-5.15.88-gentoo Linux (Gentoo 2.17)
# 2025-04-11T18:11:38.973783273Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.973806829Z [INFO] BACKTESTER-001.BacktestEngine:  MEMORY USAGE
# 2025-04-11T18:11:38.973809332Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.973817943Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Total: 94.34 GiB
# 2025-04-11T18:11:38.973821588Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Used: 11.30 GiB (11.98%)
# 2025-04-11T18:11:38.973825417Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Avail: 83.04 GiB (88.02%)
# 2025-04-11T18:11:38.973830593Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Total: 128.00 GiB
# 2025-04-11T18:11:38.973833717Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Used: 1.38 GiB (1.08%)
# 2025-04-11T18:11:38.973837302Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Avail: 126.62 GiB (98.92%)
# 2025-04-11T18:11:38.983451738Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.983465046Z [INFO] BACKTESTER-001.BacktestEngine:  IDENTIFIERS
# 2025-04-11T18:11:38.983466506Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.983470034Z [INFO] BACKTESTER-001.BacktestEngine: trader_id: BACKTESTER-001
# 2025-04-11T18:11:38.983471421Z [INFO] BACKTESTER-001.BacktestEngine: machine_id: alpha
# 2025-04-11T18:11:38.983475507Z [INFO] BACKTESTER-001.BacktestEngine: instance_id: ab8e14be-4bcf-43ac-ae45-7462226e17dd
# 2025-04-11T18:11:38.983477422Z [INFO] BACKTESTER-001.BacktestEngine: PID: 136282
# 2025-04-11T18:11:38.983478150Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.983478999Z [INFO] BACKTESTER-001.BacktestEngine:  VERSIONING
# 2025-04-11T18:11:38.983479684Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.983581944Z [INFO] BACKTESTER-001.BacktestEngine: nautilus_trader: 1.215.0
# 2025-04-11T18:11:38.983597531Z [INFO] BACKTESTER-001.BacktestEngine: python: 3.12.9
# 2025-04-11T18:11:38.983608547Z [INFO] BACKTESTER-001.BacktestEngine: numpy: 2.1.3
# 2025-04-11T18:11:38.983617749Z [INFO] BACKTESTER-001.BacktestEngine: pandas: 2.2.3
# 2025-04-11T18:11:38.983638128Z [INFO] BACKTESTER-001.BacktestEngine: msgspec: 0.19.0
# 2025-04-11T18:11:38.983667758Z [INFO] BACKTESTER-001.BacktestEngine: pyarrow: 19.0.1
# 2025-04-11T18:11:38.983681745Z [INFO] BACKTESTER-001.BacktestEngine: pytz: 2025.1
# 2025-04-11T18:11:38.983691264Z [INFO] BACKTESTER-001.BacktestEngine: uvloop: 0.21.0
# 2025-04-11T18:11:38.983693065Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2025-04-11T18:11:38.998026798Z [INFO] BACKTESTER-001.BacktestEngine: Building system kernel
# 2025-04-11T18:11:38.998138801Z [INFO] BACKTESTER-001.MessageBus: config.database=None
# 2025-04-11T18:11:38.998150108Z [INFO] BACKTESTER-001.MessageBus: config.encoding='msgpack'
# 2025-04-11T18:11:38.998154130Z [INFO] BACKTESTER-001.MessageBus: config.timestamps_as_iso8601=False
# 2025-04-11T18:11:38.998157398Z [INFO] BACKTESTER-001.MessageBus: config.buffer_interval_ms=None
# 2025-04-11T18:11:38.998160576Z [INFO] BACKTESTER-001.MessageBus: config.autotrim_mins=None
# 2025-04-11T18:11:38.998163402Z [INFO] BACKTESTER-001.MessageBus: config.use_trader_prefix=True
# 2025-04-11T18:11:38.998166009Z [INFO] BACKTESTER-001.MessageBus: config.use_trader_id=True
# 2025-04-11T18:11:38.998168361Z [INFO] BACKTESTER-001.MessageBus: config.use_instance_id=False
# 2025-04-11T18:11:38.998181312Z [INFO] BACKTESTER-001.MessageBus: config.streams_prefix='stream'
# 2025-04-11T18:11:38.998184924Z [INFO] BACKTESTER-001.MessageBus: config.types_filter=None
# 2025-04-11T18:11:38.998353257Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=commands.system.shutdown, handler=<bound method NautilusKernel._on_shutdown_system of <nautilus_trader.system.kernel.NautilusKernel object at 0x7fa9a51dfb00>>, priority=0)
# 2025-04-11T18:11:38.998438353Z [INFO] BACKTESTER-001.Cache: READY
# 2025-04-11T18:11:39.002484515Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'Portfolio.update_account' <bound method Portfolio.update_account of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x7faa06632a80>>
# 2025-04-11T18:11:39.002539189Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.order.*, handler=<bound method Portfolio.update_order of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x7faa06632a80>>, priority=10)
# 2025-04-11T18:11:39.002570356Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.position.*, handler=<bound method Portfolio.update_position of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x7faa06632a80>>, priority=10)
# 2025-04-11T18:11:39.002598446Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.account.*, handler=<bound method Portfolio.update_account of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x7faa06632a80>>, priority=10)
# 2025-04-11T18:11:39.002627970Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=data.quotes.*, handler=<bound method Portfolio.update_quote_tick of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x7faa06632a80>>, priority=10)
# 2025-04-11T18:11:39.002665907Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=data.bars.*EXTERNAL, handler=<bound method Portfolio.update_bar of <nautilus_trader.portfolio.portfolio.Portfolio object at 0x7faa06632a80>>, priority=10)
# 2025-04-11T18:11:39.002955606Z [INFO] BACKTESTER-001.DataEngine: READY
# 2025-04-11T18:11:39.003382412Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'DataEngine.execute' <bound method DataEngine.execute of DataEngine(DataEngine)>
# 2025-04-11T18:11:39.003405420Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'DataEngine.process' <bound method DataEngine.process of DataEngine(DataEngine)>
# 2025-04-11T18:11:39.003415798Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'DataEngine.request' <bound method DataEngine.request of DataEngine(DataEngine)>
# 2025-04-11T18:11:39.003424956Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'DataEngine.response' <bound method DataEngine.response of DataEngine(DataEngine)>
# 2025-04-11T18:11:39.003553639Z [INFO] BACKTESTER-001.RiskEngine: READY
# 2025-04-11T18:11:39.003827150Z [INFO] BACKTESTER-001.RiskEngine: TradingState is ACTIVE
# 2025-04-11T18:11:39.004148314Z [INFO] BACKTESTER-001.Throttler-ORDER_SUBMIT_THROTTLER: READY
# 2025-04-11T18:11:39.004273735Z [INFO] BACKTESTER-001.RiskEngine: Set MAX_ORDER_SUBMIT_RATE: 100/00:00:01
# 2025-04-11T18:11:39.004416702Z [INFO] BACKTESTER-001.Throttler-ORDER_MODIFY_THROTTLER: READY
# 2025-04-11T18:11:39.004478606Z [INFO] BACKTESTER-001.RiskEngine: Set MAX_ORDER_MODIFY_RATE: 100/00:00:01
# 2025-04-11T18:11:39.004515240Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'RiskEngine.execute' <bound method RiskEngine.execute of RiskEngine(RiskEngine)>
# 2025-04-11T18:11:39.004532133Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'RiskEngine.process' <bound method RiskEngine.process of RiskEngine(RiskEngine)>
# 2025-04-11T18:11:39.004619408Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.order.*, handler=<bound method RiskEngine._handle_event of RiskEngine(RiskEngine)>, priority=10)
# 2025-04-11T18:11:39.004702114Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.position.*, handler=<bound method RiskEngine._handle_event of RiskEngine(RiskEngine)>, priority=10)
# 2025-04-11T18:11:39.004850187Z [INFO] BACKTESTER-001.ExecEngine: READY
# 2025-04-11T18:11:39.005135926Z [INFO] BACKTESTER-001.ExecEngine: config.snapshot_orders=False
# 2025-04-11T18:11:39.005149976Z [INFO] BACKTESTER-001.ExecEngine: config.snapshot_positions=False
# 2025-04-11T18:11:39.005153341Z [INFO] BACKTESTER-001.ExecEngine: config.snapshot_positions_interval_secs=None
# 2025-04-11T18:11:39.005172016Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'ExecEngine.execute' <bound method ExecutionEngine.execute of ExecutionEngine(ExecEngine)>
# 2025-04-11T18:11:39.005181752Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'ExecEngine.process' <bound method ExecutionEngine.process of ExecutionEngine(ExecEngine)>
# 2025-04-11T18:11:39.005226044Z [DEBUG] BACKTESTER-001.Cache: Clearing index
# 2025-04-11T18:11:39.005231414Z [DEBUG] BACKTESTER-001.Cache: Cleared index
# 2025-04-11T18:11:39.005242654Z [DEBUG] BACKTESTER-001.Cache: Loading general cache from database
# 2025-04-11T18:11:39.005248645Z [INFO] BACKTESTER-001.Cache: Cached 0 general objects from database
# 2025-04-11T18:11:39.005250923Z [DEBUG] BACKTESTER-001.Cache: Loading currencies from database
# 2025-04-11T18:11:39.005255658Z [INFO] BACKTESTER-001.Cache: Cached 0 currencies from database
# 2025-04-11T18:11:39.005257673Z [DEBUG] BACKTESTER-001.Cache: Loading instruments from database
# 2025-04-11T18:11:39.005260496Z [INFO] BACKTESTER-001.Cache: Cached 0 instruments from database
# 2025-04-11T18:11:39.005262795Z [DEBUG] BACKTESTER-001.Cache: Loading accounts from database
# 2025-04-11T18:11:39.005265919Z [INFO] BACKTESTER-001.Cache: Cached 0 accounts from database
# 2025-04-11T18:11:39.005267894Z [DEBUG] BACKTESTER-001.Cache: Loading orders from database
# 2025-04-11T18:11:39.005271813Z [INFO] BACKTESTER-001.Cache: Cached 0 orders from database
# 2025-04-11T18:11:39.005274068Z [DEBUG] BACKTESTER-001.Cache: Loading order lists
# 2025-04-11T18:11:39.005277383Z [INFO] BACKTESTER-001.Cache: Cached 0 order lists from database
# 2025-04-11T18:11:39.005280156Z [DEBUG] BACKTESTER-001.Cache: Loading positions from database
# 2025-04-11T18:11:39.005282873Z [INFO] BACKTESTER-001.Cache: Cached 0 positions from database
# 2025-04-11T18:11:39.005284817Z [DEBUG] BACKTESTER-001.Cache: Building index
# 2025-04-11T18:11:39.005308798Z [DEBUG] BACKTESTER-001.Cache: Index built in 0.000s
# 2025-04-11T18:11:39.005316874Z [INFO] BACKTESTER-001.Cache: Checking data integrity
# 2025-04-11T18:11:39.005341846Z [INFO] BACKTESTER-001.Cache: Integrity check passed in 16μs
# 2025-04-11T18:11:39.005382209Z [INFO] BACKTESTER-001.ExecEngine: Loaded cache in 0ms
# 2025-04-11T18:11:39.005541237Z [INFO] BACKTESTER-001.OrderEmulator: READY
# 2025-04-11T18:11:39.005943865Z [DEBUG] BACKTESTER-001.MessageBus: Added endpoint 'OrderEmulator.execute' <bound method OrderEmulator.execute of OrderEmulator(OrderEmulator)>
# 2025-04-11T18:11:39.006050602Z [INFO] BACKTESTER-001.BACKTESTER-001: READY
# 2025-04-11T18:11:39.008205980Z [INFO] BACKTESTER-001.MACDStrategy: Initialization of MACDStrategy
# 2025-04-11T18:11:39.008471839Z [INFO] BACKTESTER-001.MACDStrategy: READY
# 2025-04-11T18:11:39.010130989Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.order.MACDStrategy-000, handler=<bound method Strategy.handle_event of MACDStrategy(MACDStrategy-000)>, priority=0)
# 2025-04-11T18:11:39.010209787Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=events.position.MACDStrategy-000, handler=<bound method Strategy.handle_event of MACDStrategy(MACDStrategy-000)>, priority=0)
# 2025-04-11T18:11:39.010264437Z [INFO] BACKTESTER-001.ExecEngine: Registered OMS.UNSPECIFIED for Strategy MACDStrategy-000
# 2025-04-11T18:11:39.010287121Z [INFO] BACKTESTER-001.BACKTESTER-001: Registered Strategy MACDStrategy-000
# 2025-04-11T18:11:39.010328255Z [INFO] BACKTESTER-001.BacktestEngine: Initialized in 267ms
# 2025-04-11T18:11:39.022252018Z [INFO] BACKTESTER-001.SimulatedExchange(BINANCE): OmsType=NETTING
# 2025-04-11T18:11:39.022466715Z [INFO] BACKTESTER-001.ExecClient-BINANCE: READY
# 2025-04-11T18:11:39.022914297Z [INFO] BACKTESTER-001.SimulatedExchange(BINANCE): Registered ExecutionClient-BINANCE
# 2025-04-11T18:11:39.022947944Z [INFO] BACKTESTER-001.ExecEngine: Registered ExecutionClient-BINANCE
# 2025-04-11T18:11:39.022966354Z [INFO] BACKTESTER-001.BacktestEngine: Added SimulatedExchange(id=BINANCE, oms_type=NETTING, account_type=MARGIN)
# 2025-04-11T18:11:39.078148566Z [INFO] BACKTESTER-001.DataClient-BINANCE: READY
# 2025-04-11T18:11:39.078242229Z [INFO] BACKTESTER-001.DataEngine: Registered BINANCE
# 2025-04-11T18:11:39.078309492Z [DEBUG] BACKTESTER-001.Cache: Added instrument APTUSDT-PERP.BINANCE
# 2025-04-11T18:11:39.078930977Z [INFO] BACKTESTER-001.SimulatedExchange(BINANCE): Added instrument APTUSDT-PERP.BINANCE and created matching engine
# 2025-04-11T18:11:39.078949475Z [INFO] BACKTESTER-001.BacktestEngine: Added APTUSDT-PERP.BINANCE Instrument
# 2025-04-11T18:11:39.458062280Z [INFO] BACKTESTER-001.BacktestEngine: Added 32_768 data elements
# 2025-04-11T18:11:39.458987725Z [DEBUG] BACKTESTER-001.Cache: Added Account(id=BINANCE-001)
# 2025-04-11T18:11:39.459009941Z [DEBUG] BACKTESTER-001.Cache: Indexed AccountId('BINANCE-001')
# 2025-04-11T18:11:39.459098048Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=True, balances=[AccountBalance(total=100.00000000 USDT, locked=0.00000000 USDT, free=100.00000000 USDT)], margins=[], event_id=60ce6b05-1a0d-4a57-aad7-0c0b72772307)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: STARTING
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.DataEngine: STARTING
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.DataClient-BINANCE: STARTING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataClient-BINANCE: Connecting...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataClient-BINANCE: Connected
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataClient-BINANCE: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataEngine: RUNNING
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.RiskEngine: STARTING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.RiskEngine: RUNNING
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.ExecEngine: STARTING
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.ExecClient-BINANCE: STARTING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecClient-BINANCE: Connecting...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecClient-BINANCE: Connected
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecClient-BINANCE: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecEngine: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.DataEngine: Connecting all clients...
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.ExecEngine: Connecting all clients...
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.OrderEmulator: STARTING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.OrderEmulator: No emulated orders to reactivate
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.OrderEmulator: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.Portfolio: Initialized 0 open orders
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.Portfolio: Initialized 0 open positions
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.BACKTESTER-001: STARTING
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.MACDStrategy: STARTING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: self.config.oms_type=None
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: self.config.external_order_claims=None
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: self.config.manage_gtd_expiry=False
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: Set ClientOrderIdGenerator client_order_id count to 0
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: Set ClientOrderIdGenerator order_list_id count to 0
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: Start of MACDStrategy
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.MessageBus: Added Subscription(topic=data.trades.BINANCE.APTUSDT-PERP, handler=<bound method Actor.handle_trade_tick of MACDStrategy(MACDStrategy-000)>, priority=0)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubscribeTradeTicks(instrument_id=APTUSDT-PERP.BINANCE, client_id=None, venue=BINANCE)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.MACDStrategy: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BACKTESTER-001: RUNNING
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine:  MEMORY USAGE
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Total: 94.34 GiB
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Used: 11.39 GiB (12.07%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: RAM-Avail: 82.95 GiB (87.93%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Total: 128.00 GiB
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Used: 1.38 GiB (1.08%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Swap-Avail: 126.62 GiB (98.92%)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine:  SimulatedVenue BINANCE
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: MarginAccount(id=BINANCE-001, type=MARGIN, base=USDT)
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: -----------------------------------------------------------------
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Balances starting:
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: 100.00000000 USDT
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine:  BACKTEST RUN
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: =================================================================
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Run config ID:  d267e38b1bc9e3b27eaa75bcbc5b59c25b4ef98a07fae7a99defd195ae77a235
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Run ID:         f95c8905-c895-4f0b-8923-9d04f45a0a1a
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Run started:    2025-04-11T18:11:39.458692000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Backtest start: 2024-12-10T00:00:04.998000000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Batch start:    2024-12-10T00:00:04.998000000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: Batch end:      2024-12-10T00:20:05.689000000Z
# 2024-12-10T00:00:04.998000000Z [INFO] BACKTESTER-001.BacktestEngine: -----------------------------------------------------------------
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93610,0.9,BUYER,245140976,1733788804998000000)
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93660,0.9,BUYER,245140977,1733788804998000000)
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93700,0.9,BUYER,245140978,1733788804998000000)
# 2024-12-10T00:00:04.998000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93730,7.3,BUYER,245140979,1733788804998000000)
# 2024-12-10T00:00:05.018000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93550,4.0,SELLER,245140980,1733788805018000000)
# 2024-12-10T00:00:05.018000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93460,16.9,SELLER,245140981,1733788805018000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93450,0.5,SELLER,245140982,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93400,38.4,SELLER,245140983,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93380,14.7,SELLER,245140984,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93370,0.5,SELLER,245140985,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93360,0.9,SELLER,245140986,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93350,0.5,SELLER,245140987,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93330,0.9,SELLER,245140988,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93300,1.4,SELLER,245140989,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93260,5.8,SELLER,245140990,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93250,0.9,SELLER,245140991,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93240,1.4,SELLER,245140992,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93230,10.9,SELLER,245140993,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93220,19.0,SELLER,245140994,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93210,22.9,SELLER,245140995,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93200,39.4,SELLER,245140996,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93190,0.5,SELLER,245140997,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93170,23.4,SELLER,245140998,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93150,11.8,SELLER,245140999,1733788805024000000)
# 2024-12-10T00:00:05.024000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93140,15.2,SELLER,245141000,1733788805024000000)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93570,1.0,SELLER,245141001,1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, side=SELL, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-1, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-1, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=1.0 @ 11.93570, ask=1.0 @ 11.93570, last=11.93570
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000005-001-000-1, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=None, fills=[(Price(11.93570), Quantity(1.0))]
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000005-001-000-1') with VenueOrderId('BINANCE-1-001')
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=99.99403215 USDT, locked=0.00000000 USDT, free=99.99403215 USDT)], margins=[], event_id=90130d8f-034e-422a-a880-91552031f543)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, venue_order_id=BINANCE-1-001, account_id=BINANCE-001, trade_id=BINANCE-1-001, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=1.0, last_px=11.93570 USDT, commission=0.00596785 USDT, liquidity_side=TAKER, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, venue_order_id=BINANCE-1-001, account_id=BINANCE-001, trade_id=BINANCE-1-001, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=1.0, last_px=11.93570 USDT, commission=0.00596785 USDT, liquidity_side=TAKER, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Indexed PositionId('APTUSDT-PERP.BINANCE-MACDStrategy-000'), client_order_id=O-20241210-000005-001-000-1, strategy_id=MACDStrategy-000)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Added Position(id=APTUSDT-PERP.BINANCE-MACDStrategy-000, strategy_id=MACDStrategy-000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-1.0
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.03043604 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000005-001-000-1, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-1.0, quantity=1.0, peak_qty=1.0, currency=USDT, avg_px_open=11.9357, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.00596785 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788805048000000, ts_last=1733788805048000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, side=BUY, type=STOP_MARKET, quantity=1.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': '12.53250', 'trigger_type': 'LAST_PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['STOP'])
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Added StopMarketOrder(BUY 1.0 APTUSDT-PERP.BINANCE STOP_MARKET @ 12.53250[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-2, venue_order_id=None, position_id=None, tags=['STOP'])
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=StopMarketOrder(BUY 1.0 APTUSDT-PERP.BINANCE STOP_MARKET @ 12.53250[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-2, venue_order_id=None, position_id=None, tags=['STOP']), position_id=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-3, side=BUY, type=LIMIT, quantity=1.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'price': '11.33890', 'display_qty': None, 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Added LimitOrder(BUY 1.0 APTUSDT-PERP.BINANCE LIMIT @ 11.33890 GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-3, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=LimitOrder(BUY 1.0 APTUSDT-PERP.BINANCE LIMIT @ 11.33890 GTC, status=INITIALIZED, client_order_id=O-20241210-000005-001-000-3, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT']), position_id=None)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-3, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.00000000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=97.01609995 USDT, locked=0.03043604 USDT, free=96.98566391 USDT)], margins=[MarginBalance(initial=0.00000000 USDT, maintenance=0.03043604 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=2bb2e661-35d9-4c42-a7e9-d0320ae29fb4)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, venue_order_id=BINANCE-1-001, account_id=BINANCE-001, trade_id=BINANCE-1-002, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=499.0, last_px=11.93560 USDT, commission=2.97793220 USDT, liquidity_side=TAKER, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-1, venue_order_id=BINANCE-1-001, account_id=BINANCE-001, trade_id=BINANCE-1-002, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=499.0, last_px=11.93560 USDT, commission=2.97793220 USDT, liquidity_side=TAKER, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-500.0
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.21789000 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000005-001-000-1, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-500.0, quantity=500.0, peak_qty=500.0, currency=USDT, avg_px_open=11.935600200000001, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-2.98390005 USDT, unrealized_pnl=0.00010000 USDT, ts_opened=1733788805048000000, ts_last=1733788805048000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000005-001-000-2') with VenueOrderId('BINANCE-1-002')
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.06391575 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=97.01609995 USDT, locked=15.28180575 USDT, free=81.73429420 USDT)], margins=[MarginBalance(initial=0.06391575 USDT, maintenance=15.21789000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=99e098b8-b692-4889-9617-85c48e11104c)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-2, venue_order_id=BINANCE-1-002, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: After stop loss order accepted balances locked: 15.28180575
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000005-001-000-3') with VenueOrderId('BINANCE-1-003')
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.12174414 USDT
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=97.01609995 USDT, locked=15.33963414 USDT, free=81.67646581 USDT)], margins=[MarginBalance(initial=0.12174414 USDT, maintenance=15.21789000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=c722c063-6fd9-4ed0-9f05-73b02f7e2585)
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-3, venue_order_id=BINANCE-1-003, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000005-001-000-3, venue_order_id=BINANCE-1-003, account_id=BINANCE-001, ts_event=1733788805048000000)
# 2024-12-10T00:00:05.048000000Z [INFO] BACKTESTER-001.MACDStrategy: After take profit order accepted balances locked: 15.33963414
# 2024-12-10T00:00:05.048000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93540,3.7,SELLER,245141002,1733788805048000000)
# 2024-12-10T00:00:05.089000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93140,1.4,SELLER,245141003,1733788805089000000)
# 2024-12-10T00:00:05.147000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93360,31.5,BUYER,245141004,1733788805147000000)
# 2024-12-10T00:00:05.236000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93190,0.6,SELLER,245141005,1733788805236000000)
# 2024-12-10T00:00:05.236000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93140,1.1,SELLER,245141006,1733788805236000000)
# 2024-12-10T00:00:05.275000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93330,93.9,SELLER,245141007,1733788805275000000)
# 2024-12-10T00:00:05.306000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93270,75.2,SELLER,245141008,1733788805306000000)
# 2024-12-10T00:00:05.312000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93120,12.1,SELLER,245141009,1733788805312000000)
# 2024-12-10T00:00:05.333000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93300,25.3,BUYER,245141010,1733788805333000000)
# 2024-12-10T00:00:05.353000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93130,22.9,SELLER,245141011,1733788805353000000)
# 2024-12-10T00:00:05.353000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93120,5.2,SELLER,245141012,1733788805353000000)
# 2024-12-10T00:00:05.353000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93100,32.8,SELLER,245141013,1733788805353000000)
# 2024-12-10T00:00:05.355000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93300,16.5,BUYER,245141014,1733788805355000000)
# 2024-12-10T00:00:05.355000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93310,0.5,BUYER,245141015,1733788805355000000)
# 2024-12-10T00:00:05.406000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93100,24.8,SELLER,245141016,1733788805406000000)
# 2024-12-10T00:00:05.417000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93080,1.9,SELLER,245141017,1733788805417000000)
# 2024-12-10T00:00:05.417000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93050,0.5,SELLER,245141018,1733788805417000000)
# 2024-12-10T00:00:05.417000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93040,0.7,SELLER,245141019,1733788805417000000)
# 2024-12-10T00:00:05.662000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93280,12.0,BUYER,245141020,1733788805662000000)
# 2024-12-10T00:00:06.198000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93270,0.1,SELLER,245141021,1733788806198000000)
# 2024-12-10T00:00:06.230000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93280,101.8,BUYER,245141022,1733788806230000000)
# 2024-12-10T00:00:06.331000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.12174414 USDT
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=97.02951679 USDT, locked=15.33963414 USDT, free=81.68988265 USDT)], margins=[MarginBalance(initial=0.12174414 USDT, maintenance=15.21789000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=db487d25-d677-413d-bdc8-14c584235cef)
# 2024-12-10T00:00:08.205000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-4, venue_order_id=BINANCE-1-004, account_id=BINANCE-001, trade_id=BINANCE-1-003, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=8.2, last_px=11.92800 USDT, commission=0.04890480 USDT, liquidity_side=TAKER, ts_event=1733788808205000000)
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-4, venue_order_id=BINANCE-1-004, account_id=BINANCE-001, trade_id=BINANCE-1-003, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=8.2, last_px=11.92800 USDT, commission=0.04890480 USDT, liquidity_side=TAKER, ts_event=1733788808205000000)
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-491.8
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=14.96831660 USDT
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000005-001-000-1, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-491.8, quantity=491.8, peak_qty=500.0, currency=USDT, avg_px_open=11.935600200000001, avg_px_close=11.928, realized_return=0.00064, realized_pnl=-2.97048321 USDT, unrealized_pnl=3.73777836 USDT, ts_opened=1733788805048000000, ts_last=1733788808205000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:08.205000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(3.68859836, USDT)]
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.12174414 USDT
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=97.78499536 USDT, locked=15.09006074 USDT, free=82.69493462 USDT)], margins=[MarginBalance(initial=0.12174414 USDT, maintenance=14.96831660 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=b79c6d43-a578-4728-966b-6aee09d86fc1)
# 2024-12-10T00:00:08.205000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-4, venue_order_id=BINANCE-1-004, account_id=BINANCE-001, trade_id=BINANCE-1-004, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=491.8, last_px=11.92810 USDT, commission=2.93311979 USDT, liquidity_side=TAKER, ts_event=1733788808205000000)
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-4, venue_order_id=BINANCE-1-004, account_id=BINANCE-001, trade_id=BINANCE-1-004, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=491.8, last_px=11.92810 USDT, commission=2.93311979 USDT, liquidity_side=TAKER, ts_event=1733788808205000000)
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=0
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.00000000 USDT
# 2024-12-10T00:00:08.205000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionClosed(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000005-001-000-1, closing_order_id=O-20241210-000008-001-000-4, entry=SELL, side=FLAT, signed_qty=0.0, quantity=0.0, peak_qty=500.0, currency=USDT, avg_px_open=11.935600200000001, avg_px_close=11.92809836, realized_return=0.00063, realized_pnl=-2.21500464 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788805048000000, ts_last=1733788808205000000, ts_closed=1733788808205000000, duration_ns=3157000000)
# 2024-12-10T00:00:08.205000000Z [WARN] BACKTESTER-001.MACDStrategy: <--[EVT] OrderRejected(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-5, account_id=BINANCE-001, reason='REDUCE_ONLY MARKET BUY order would have increased position', ts_event=1733788808205000000)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92810,0.9,BUYER,245141087,1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-6, side=BUY, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000008-001-000-6, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000008-001-000-6, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-6, account_id=BINANCE-001, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=0.9 @ 11.92810, ask=0.9 @ 11.92810, last=11.92810
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000008-001-000-6, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=None, fills=[(Price(11.92810), Quantity(0.9))]
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000008-001-000-6') with VenueOrderId('BINANCE-1-005')
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.12174414 USDT
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=97.77962771 USDT, locked=0.12174414 USDT, free=97.65788357 USDT)], margins=[MarginBalance(initial=0.12174414 USDT, maintenance=0.00000000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=cc15575c-92a0-419a-9953-1603c9590029)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-6, venue_order_id=BINANCE-1-005, account_id=BINANCE-001, trade_id=BINANCE-1-005, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=0.9, last_px=11.92810 USDT, commission=0.00536765 USDT, liquidity_side=TAKER, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-6, venue_order_id=BINANCE-1-005, account_id=BINANCE-001, trade_id=BINANCE-1-005, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=0.9, last_px=11.92810 USDT, commission=0.00536765 USDT, liquidity_side=TAKER, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Snapshot Position(FLAT APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-572e-4076-8486-8fe4a23f1013)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=0.9
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.02737499 USDT
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000008-001-000-6, closing_order_id=None, entry=BUY, side=LONG, signed_qty=0.9, quantity=0.9, peak_qty=0.9, currency=USDT, avg_px_open=11.9281, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.00536765 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788808218000000, ts_last=1733788808218000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-7, side=SELL, type=STOP_MARKET, quantity=0.9, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': '11.33170', 'trigger_type': 'LAST_PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['STOP'])
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Added StopMarketOrder(SELL 0.9 APTUSDT-PERP.BINANCE STOP_MARKET @ 11.33170[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000008-001-000-7, venue_order_id=None, position_id=None, tags=['STOP'])
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=StopMarketOrder(SELL 0.9 APTUSDT-PERP.BINANCE STOP_MARKET @ 11.33170[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000008-001-000-7, venue_order_id=None, position_id=None, tags=['STOP']), position_id=None)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-7, account_id=BINANCE-001, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-8, side=SELL, type=LIMIT, quantity=0.9, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'price': '12.52450', 'display_qty': None, 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Added LimitOrder(SELL 0.9 APTUSDT-PERP.BINANCE LIMIT @ 12.52450 GTC, status=INITIALIZED, client_order_id=O-20241210-000008-001-000-8, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=LimitOrder(SELL 0.9 APTUSDT-PERP.BINANCE LIMIT @ 12.52450 GTC, status=INITIALIZED, client_order_id=O-20241210-000008-001-000-8, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT']), position_id=None)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-8, account_id=BINANCE-001, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.12174414 USDT
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=94.80294540 USDT, locked=0.14911913 USDT, free=94.65382627 USDT)], margins=[MarginBalance(initial=0.12174414 USDT, maintenance=0.02737499 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=da7f8041-710c-416f-bc0c-c8001bf99b98)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-6, venue_order_id=BINANCE-1-005, account_id=BINANCE-001, trade_id=BINANCE-1-006, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=499.1, last_px=11.92820 USDT, commission=2.97668231 USDT, liquidity_side=TAKER, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-6, venue_order_id=BINANCE-1-005, account_id=BINANCE-001, trade_id=BINANCE-1-006, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=499.1, last_px=11.92820 USDT, commission=2.97668231 USDT, liquidity_side=TAKER, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=500.0
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.20845500 USDT
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000,

# %%
from nautilus_trader.backtest.engine import BacktestEngine
from nautilus_trader.model import Venue


engine: BacktestEngine = node.get_engine(config.id)

engine.trader.generate_order_fills_report()
# Out:
#  account_id=BINANCE-001, opening_order_id=O-20241210-000008-001-000-6, closing_order_id=None, entry=BUY, side=LONG, signed_qty=500.0, quantity=500.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92819982, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-2.98204996 USDT, unrealized_pnl=0.00009000 USDT, ts_opened=1733788808218000000, ts_last=1733788808218000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000008-001-000-7') with VenueOrderId('BINANCE-1-006')
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.17375664 USDT
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=94.80294540 USDT, locked=15.38221164 USDT, free=79.42073376 USDT)], margins=[MarginBalance(initial=0.17375664 USDT, maintenance=15.20845500 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=4d96b78a-3022-4289-95f9-de4dcdb55d7c)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-7, venue_order_id=BINANCE-1-006, account_id=BINANCE-001, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-7, venue_order_id=BINANCE-1-006, account_id=BINANCE-001, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: After stop loss order accepted balances locked: 15.38221164
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000008-001-000-8') with VenueOrderId('BINANCE-1-007')
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.23124410 USDT
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=94.80294540 USDT, locked=15.43969910 USDT, free=79.36324630 USDT)], margins=[MarginBalance(initial=0.23124410 USDT, maintenance=15.20845500 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=49f6b90b-dd0b-495a-b34b-5fb949ef6b3f)
# 2024-12-10T00:00:08.218000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000008-001-000-8, venue_order_id=BINANCE-1-007, account_id=BINANCE-001, ts_event=1733788808218000000)
# 2024-12-10T00:00:08.218000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-
000)
# 2024-12-10T00:00:09.433000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93190,8.2,BUYER,245141127,1733788809433000000)
# 2024-12-10T00:00:09.433000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93200,4.5,BUYER,245141128,1733788809433000000)
# 2024-12-10T00:00:09.433000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93210,115.4,BUYER,245141129,1733788809433000000)
# 2024-12-10T00:00:09.433000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93280,51.8,BUYER,245141130,1733788809433000000)
# 2024-12-10T00:00:09.433000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93290,31.5,BUYER,245141131,1733788809433000000)
# 2024-12-10T00:00:09.565000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93070,0.9,SELLER,245141132,1733788809565000000)
# 2024-12-10T00:00:09.565000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93060,3.8,SELLER,245141133,1733788809565000000)
# 2024-12-10T00:00:09.603000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93060,16.7,BUYER,245141134,1733788809603000000)
# 2024-12-10T00:00:09.603000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93070,29.6,BUYER,245141135,1733788809603000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93050,19.2,SELLER,245141136,1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93000,1.4,SELLER,245141137,1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-9, side=SELL, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-9, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Indexed PositionId('APTUSDT-PERP.BINANCE-MACDStrategy-000'), client_order_id=O-20241210-000009-001-000-9, strategy_id=MACDStrategy-000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-9, venue_order_id=None, position_id=None, tags=None), position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-9, account_id=BINANCE-001, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=1.4 @ 11.93000, ask=1.4 @ 11.93000, last=11.93000
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000009-001-000-9, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=Position(LONG 500.0 APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000), fills=[(Price(11.93000), Quantity(1.4))]
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000009-001-000-9') with VenueOrderId('BINANCE-1-008')
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(0.00252025, USDT)]
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.23124410 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=94.79711465 USDT, locked=15.43969910 USDT, free=79.35741555 USDT)], margins=[MarginBalance(initial=0.23124410 USDT, maintenance=15.20845500 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=37795794-50f2-4ccb-b3e9-f1eea2b8f874)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-9, venue_order_id=BINANCE-1-008, account_id=BINANCE-001, trade_id=BINANCE-1-007, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=1.4, last_px=11.93000 USDT, commission=0.00835100 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-9, venue_order_id=BINANCE-1-008, account_id=BINANCE-001, trade_id=BINANCE-1-007, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=1.4, last_px=11.93000 USDT, commission=0.00835100 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=498.6
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.16587133 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000008-001-000-6, closing_order_id=None, entry=BUY, side=LONG, signed_qty=498.6, quantity=498.6, peak_qty=500.0, currency=USDT, avg_px_open=11.92819982, avg_px_close=11.93, realized_return=0.00015, realized_pnl=-2.98788071 USDT, unrealized_pnl=0.89756975 USDT, ts_opened=1733788808218000000, ts_last=1733788809609000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(0.84770975, USDT)]
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.23124410 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=92.67070033 USDT, locked=15.39711543 USDT, free=77.27358490 USDT)], margins=[MarginBalance(initial=0.23124410 USDT, maintenance=15.16587133 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=7bc04b86-7479-4952-88b6-a8fd62abfedd)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-9, venue_order_id=BINANCE-1-008, account_id=BINANCE-001, trade_id=BINANCE-1-008, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=498.6, last_px=11.92990 USDT, commission=2.97412407 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-9, venue_order_id=BINANCE-1-008, account_id=BINANCE-001, trade_id=BINANCE-1-008, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=498.6, last_px=11.92990 USDT, commission=2.97412407 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=0
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.00000000 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionClosed(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000008-001-000-6, closing_order_id=O-20241210-000009-001-000-9, entry=BUY, side=FLAT, signed_qty=0.0, quantity=0.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92819982, avg_px_close=11.929900280000002, realized_return=0.00014, realized_pnl=-5.11429503 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788808218000000, ts_last=1733788809609000000, ts_closed=1733788809609000000, duration_ns=1391000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92990,0.9,SELLER,245141138,1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-10, side=SELL, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-10, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-10, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-10, account_id=BINANCE-001, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=0.9 @ 11.92990, ask=0.9 @ 11.92990, last=11.92990
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000009-001-000-10, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=None, fills=[(Price(11.92990), Quantity(0.9))]
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000009-001-000-10') with VenueOrderId('BINANCE-1-009')
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.23124410 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=92.66533187 USDT, locked=0.23124410 USDT, free=92.43408777 USDT)], margins=[MarginBalance(initial=0.23124410 USDT, maintenance=0.00000000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=9d36c83d-2b73-4f7d-9451-91aa58ecb68d)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-10, venue_order_id=BINANCE-1-009, account_id=BINANCE-001, trade_id=BINANCE-1-009, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=0.9, last_px=11.92990 USDT, commission=0.00536846 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-10, venue_order_id=BINANCE-1-009, account_id=BINANCE-001, trade_id=BINANCE-1-009, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=0.9, last_px=11.92990 USDT, commission=0.00536846 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Snapshot Position(FLAT APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-14e0-477f-b4d1-0842aef8caf3)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-0.9
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.02737912 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000009-001-000-10, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-0.9, quantity=0.9, peak_qty=0.9, currency=USDT, avg_px_open=11.9299, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.00536846 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788809609000000, ts_last=1733788809609000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-11, side=BUY, type=STOP_MARKET, quantity=0.9, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': '12.52640', 'trigger_type': 'LAST_PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['STOP'])
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Added StopMarketOrder(BUY 0.9 APTUSDT-PERP.BINANCE STOP_MARKET @ 12.52640[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-11, venue_order_id=None, position_id=None, tags=['STOP'])
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=StopMarketOrder(BUY 0.9 APTUSDT-PERP.BINANCE STOP_MARKET @ 12.52640[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-11, venue_order_id=None, position_id=None, tags=['STOP']), position_id=None)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-11, account_id=BINANCE-001, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-12, side=BUY, type=LIMIT, quantity=0.9, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'price': '11.33340', 'display_qty': None, 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Added LimitOrder(BUY 0.9 APTUSDT-PERP.BINANCE LIMIT @ 11.33340 GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-12, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=LimitOrder(BUY 0.9 APTUSDT-PERP.BINANCE LIMIT @ 11.33340 GTC, status=INITIALIZED, client_order_id=O-20241210-000009-001-000-12, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT']), position_id=None)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-12, account_id=BINANCE-001, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.23124410 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=89.68825028 USDT, locked=0.25862322 USDT, free=89.42962706 USDT)], margins=[MarginBalance(initial=0.23124410 USDT, maintenance=0.02737912 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=95178483-d1a5-49e9-b308-052bc33a63dd)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-10, venue_order_id=BINANCE-1-009, account_id=BINANCE-001, trade_id=BINANCE-1-010, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=499.1, last_px=11.92980 USDT, commission=2.97708159 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-10, venue_order_id=BINANCE-1-009, account_id=BINANCE-001, trade_id=BINANCE-1-010, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=499.1, last_px=11.92980 USDT, commission=2.97708159 USDT, liquidity_side=TAKER, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-500.0
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.21049500 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000009-001-000-10, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-500.0, quantity=500.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92980018, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-2.98245005 USDT, unrealized_pnl=0.00009000 USDT, ts_opened=1733788809609000000, ts_last=1733788809609000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000009-001-000-11') with VenueOrderId('BINANCE-1-010')
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.28874028 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=89.68825028 USDT, locked=15.49923528 USDT, free=74.18901500 USDT)], margins=[MarginBalance(initial=0.28874028 USDT, maintenance=15.21049500 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=fe29f652-bd00-45f8-a140-38c168ac3c8d)
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-11, venue_order_id=BINANCE-1-010, account_id=BINANCE-001, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000009-001-000-11, venue_order_id=BINANCE-1-010, account_id=BINANCE-001, ts_event=1733788809609000000)
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.MACDStrategy: After stop loss order accepted balances locked: 15.49923528
# 2024-12-10T00:00:09.609000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000009-001-000-12') with VenueOrderId('BINANCE-1-011')
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.34076059 USDT
# 2024-12-10T00:00:09.609000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=89.68825028 USDT, locked=15.55125559 USDT, free=74.13699469 USDT)], margins=[MarginBalance(initial=0.34076059 USDT, maintenance=15.21049500 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id
# O-20241210-000010-001-000-23  BINANCE-001  BINANCE-1-022  MARKET   BUY
# O-20241210-000010-001-000-26  BINANCE-001  BINANCE-1-024  MARKET  SELL
# O-20241210-000010-001-000-27  BINANCE-001  BINANCE-1-026  MARKET  SELL
# O-20241210-000010-001-000-30  BINANCE-001  BINANCE-1-028  MARKET   BUY
# O-20241210-000010-001-000-31  BINANCE-001  BINANCE-1-030  MARKET   BUY
# O-20241210-000011-001-000-34  BINANCE-001  BINANCE-1-032  MARKET  SELL
# O-20241210-000011-001-000-35  BINANCE-001  BINANCE-1-034  MARKET  SELL
# O-20241210-000011-001-000-38  BINANCE-001  BINANCE-1-036  MARKET   BUY
# O-20241210-000011-001-000-39  BINANCE-001  BINANCE-1-038  MARKET  SELL
# O-20241210-000012-001-000-42  BINANCE-001  BINANCE-1-040  MARKET   BUY
# O-20241210-000012-001-000-43  BINANCE-001  BINANCE-1-042  MARKET   BUY
# O-20241210-002005-001-000-46  BINANCE-001  BINANCE-1-043  MARKET  SELL
# O-20241210-002005-001-000-47  BINANCE-001  BINANCE-1-044  MARKET  SELL
# O-20241210-020718-001-000-48  BINANCE-001  BINANCE-1-045  MARKET  SELL
# O-20241210-020718-001-000-49  BINANCE-001  BINANCE-1-046  MARKET  SELL
# O-20241210-024303-001-000-50  BINANCE-001  BINANCE-1-048  MARKET  SELL
# O-20241210-024303-001-000-51  BINANCE-001  BINANCE-1-049  MARKET  SELL
# O-20241210-030923-001-000-52  BINANCE-001  BINANCE-1-050  MARKET  SELL
#
#                              quantity  ... exec_spawn_id           tags  \
# client_order_id                        ...
# O-20241210-000005-001-000-1     500.0  ...          None           None
# O-20241210-000005-001-000-3       1.0  ...          None  [TAKE_PROFIT]
# O-20241210-000008-001-000-4     500.0  ...          None           None
# O-20241210-000008-001-000-6     500.0  ...          None           None
# O-20241210-000009-001-000-10    500.0  ...          None           None
# O-20241210-000009-001-000-9     500.0  ...          None           None
# O-20241210-000010-001-000-13    500.0  ...          None           None
# O-20241210-000010-001-000-15    500.0  ...          None           None
# O-20241210-000010-001-000-18    500.0  ...          None           None
# O-20241210-000010-001-000-19    500.0  ...          None           None
# O-20241210-000010-001-000-22    500.0  ...          None           None
# O-20241210-000010-001-000-23    500.0  ...          None           None
# O-20241210-000010-001-000-26    500.0  ...          None           None
# O-20241210-000010-001-000-27    500.0  ...          None           None
# O-20241210-000010-001-000-30    500.0  ...          None           None
# O-20241210-000010-001-000-31    500.0  ...          None           None
# O-20241210-000011-001-000-34    500.0  ...          None           None
# O-20241210-000011-001-000-35    500.0  ...          None           None
# O-20241210-000011-001-000-38    500.0  ...          None           None
# O-20241210-000011-001-000-39    500.0  ...          None           None
# O-20241210-000012-001-000-42    500.0  ...          None           None
# O-20241210-000012-001-000-43    500.0  ...          None           None
# O-20241210-002005-001-000-46    500.0  ...          None           None
# O-20241210-002005-001-000-47    500.0  ...          None           None
# O-20241210-020718-001-000-48    500.0  ...          None           None
# O-20241210-020718-001-000-49    500.0  ...          None           None
# O-20241210-024303-001-000-50    500.0  ...          None           None
000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91210,30.4,SELLER,245141276,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91200,1.4,SELLER,245141277,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91180,39.6,SELLER,245141278,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91170,1.3,SELLER,245141279,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91160,16.8,SELLER,245141280,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91150,75.8,SELLER,245141281,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91140,0.5,SELLER,245141282,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91120,99.5,SELLER,245141283,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91110,45.7,SELLER,245141284,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91100,0.8,SELLER,245141285,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91090,24.2,SELLER,245141286,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91080,93.8,SELLER,245141287,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91060,116.5,SELLER,245141288,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91030,84.3,SELLER,245141289,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91020,0.5,SELLER,245141290,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91010,144.5,SELLER,245141291,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91000,521.8,SELLER,245141292,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90990,45.7,SELLER,245141293,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90980,18.3,SELLER,245141294,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90970,23.3,SELLER,245141295,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90960,2.3,SELLER,245141296,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90940,22.8,SELLER,245141297,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90920,84.2,SELLER,245141298,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90910,23.3,SELLER,245141299,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90900,2.3,SELLER,245141300,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90890,10.9,SELLER,245141301,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90880,51.0,SELLER,245141302,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90870,45.7,SELLER,245141303,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90860,0.9,SELLER,245141304,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90850,189.1,SELLER,245141305,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90840,1.9,SELLER,245141306,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90830,0.9,SELLER,245141307,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90820,0.5,SELLER,245141308,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90810,17.5,SELLER,245141309,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90800,0.9,SELLER,245141310,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90780,82.7,SELLER,245141311,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90770,83.8,SELLER,245141312,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90760,33.4,SELLER,245141313,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90750,46.6,SELLER,245141314,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90740,218.7,SELLER,245141315,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90730,39.9,SELLER,245141316,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90710,41.2,SELLER,245141317,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90700,273.2,SELLER,245141318,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90690,226.2,SELLER,245141319,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90660,486.2,SELLER,245141320,1733788810100000000)
# 2024-12-10T00:00:10.100000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.90650,1675.5,SELLER,245141321,1733788810100000000)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.93060,33.3,SELLER,245141322,1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-13, side=BUY, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-13, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-13, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-13, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-14, side=BUY, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-14, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Indexed PositionId('APTUSDT-PERP.BINANCE-MACDStrategy-000'), client_order_id=O-20241210-000010-001-000-14, strategy_id=MACDStrategy-000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-14, venue_order_id=None, position_id=None, tags=None), position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-14, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=33.3 @ 11.93060, ask=33.3 @ 11.93060, last=11.93060
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-13, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=Position(SHORT 500.0 APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000), fills=[(Price(11.93060), Quantity(33.3))]
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-13') with VenueOrderId('BINANCE-1-012')
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-0.02663401, USDT)]
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.34076059 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=89.46297178 USDT, locked=15.55125559 USDT, free=73.91171619 USDT)], margins=[MarginBalance(initial=0.34076059 USDT, maintenance=15.21049500 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=ecba61eb-49b8-4b79-a865-5fa14be0de6c)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-13, venue_order_id=BINANCE-1-012, account_id=BINANCE-001, trade_id=BINANCE-1-011, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=33.3, last_px=11.93060 USDT, commission=0.19864449 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-13, venue_order_id=BINANCE-1-012, account_id=BINANCE-001, trade_id=BINANCE-1-011, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=33.3, last_px=11.93060 USDT, commission=0.19864449 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-466.7
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=14.19747603 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000009-001-000-10, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-466.7, quantity=466.7, peak_qty=500.0, currency=USDT, avg_px_open=11.92980018, avg_px_close=11.9306, realized_return=-0.00007, realized_pnl=-3.20772855 USDT, unrealized_pnl=-0.37327599 USDT, ts_opened=1733788809609000000, ts_last=1733788810101000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-0.41994599, USDT)]
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.34076059 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=86.25899694 USDT, locked=14.53823662 USDT, free=71.72076032 USDT)], margins=[MarginBalance(initial=0.34076059 USDT, maintenance=14.19747603 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=eb2cb0a5-4c98-4e68-a3d2-b834d5662bfd)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-13, venue_order_id=BINANCE-1-012, account_id=BINANCE-001, trade_id=BINANCE-1-012, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=466.7, last_px=11.93070 USDT, commission=2.78402885 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-13, venue_order_id=BINANCE-1-012, account_id=BINANCE-001, trade_id=BINANCE-1-012, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=466.7, last_px=11.93070 USDT, commission=2.78402885 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=0
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.00000000 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionClosed(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000009-001-000-10, closing_order_id=O-20241210-000010-001-000-13, entry=SELL, side=FLAT, signed_qty=0.0, quantity=0.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92980018, avg_px_close=11.93069334, realized_return=-0.00007, realized_pnl=-6.41170339 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788809609000000, ts_last=1733788810101000000, ts_closed=1733788810101000000, duration_ns=492000000)
# 2024-12-10T00:00:10.101000000Z [WARN] BACKTESTER-001.MACDStrategy: <--[EVT] OrderRejected(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-14, account_id=BINANCE-001, reason='REDUCE_ONLY MARKET BUY order would have increased position', ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92820,31.4,SELLER,245141323,1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, side=BUY, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-15, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-15, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=31.4 @ 11.92820, ask=31.4 @ 11.92820, last=11.92820
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-15, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=None, fills=[(Price(11.92820), Quantity(31.4))]
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-15') with VenueOrderId('BINANCE-1-013')
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.34076059 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=86.07172420 USDT, locked=0.34076059 USDT, free=85.73096361 USDT)], margins=[MarginBalance(initial=0.34076059 USDT, maintenance=0.00000000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=e2b30df1-97e7-45f6-84ce-3b989410aa6d)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, venue_order_id=BINANCE-1-013, account_id=BINANCE-001, trade_id=BINANCE-1-013, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=31.4, last_px=11.92820 USDT, commission=0.18727274 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, venue_order_id=BINANCE-1-013, account_id=BINANCE-001, trade_id=BINANCE-1-013, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=31.4, last_px=11.92820 USDT, commission=0.18727274 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Snapshot Position(FLAT APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-7efd-4fe7-8ab8-ebbc8caa9ef6)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=31.4
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.95509097 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-15, closing_order_id=None, entry=BUY, side=LONG, signed_qty=31.4, quantity=31.4, peak_qty=31.4, currency=USDT, avg_px_open=11.9282, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.18727274 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788810101000000, ts_last=1733788810101000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-16, side=SELL, type=STOP_MARKET, quantity=31.4, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': '11.33180', 'trigger_type': 'LAST_PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['STOP'])
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Added StopMarketOrder(SELL 31.4 APTUSDT-PERP.BINANCE STOP_MARKET @ 11.33180[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-16, venue_order_id=None, position_id=None, tags=['STOP'])
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=StopMarketOrder(SELL 31.4 APTUSDT-PERP.BINANCE STOP_MARKET @ 11.33180[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-16, venue_order_id=None, position_id=None, tags=['STOP']), position_id=None)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-
#                                                          trader_id  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...  BACKTESTER-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000               BACKTESTER-001
#
#                                                          strategy_id  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...  MACDStrategy-000
# APTUSDT-PERP.BINANCE-MACDStrategy-000               MACDStrategy-000
#
#                                                            instrument_id  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...  APTUSDT-PERP.BINANCE
# APTUSDT-PERP.BINANCE-MACDStrategy-000               APTUSDT-PERP.BINANCE
#
#                                                      account_id  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...  BINANCE-001
# APTUSDT-PERP.BINANCE-MACDStrategy-000               BINANCE-001
#
#                                                                 opening_order_id  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...   O-20241210-000005-001-000-1
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...   O-20241210-000008-001-000-6
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  O-20241210-000009-001-000-10
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...     11.919400
# APTUSDT-PERP.BINANCE-MACDStrategy-000                        NaN
#
#                                                           commissions  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...  [5.96592464 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...  [5.96452503 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  [5.96512339 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...  [5.96222758 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...  [5.96019875 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...  [5.96040062 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...  [5.96040323 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...  [5.96057501 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...  [5.96007485 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...  [5.95915038 USDT]
# APTUSDT-PERP.BINANCE-MACDStrategy-000               [2.97992496 USDT]
#
#                                                     realized_return  \
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...          0.00063
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...          0.00014
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...         -0.00007
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...         -0.00064
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...         -0.00020
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...         -0.00015
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...         -0.00012
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...         -0.00008
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...          0.00008
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...         -0.00018
# APTUSDT-PERP.BINANCE-MACDStrategy-000                       0.00000
#
#                                                         realized_pnl
# position_id
# APTUSDT-PERP.BINANCE-MACDStrategy-000-71f6e74b-...  -2.21500464 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-e0d8da33-...  -5.11429503 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-87fbceac-...  -6.41170339 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-...  -9.80078758 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-...  -7.15432875 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-ec5226f2-...  -6.85593062 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-4e04cc94-...  -6.64979323 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-417497dd-...  -6.41039501 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-c2565a4a-...  -5.50948485 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000-a02c6bd8-...  -7.05822038 USDT
# APTUSDT-PERP.BINANCE-MACDStrategy-000               -2.97992496 USDT
# 001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-16, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-17, side=SELL, type=LIMIT, quantity=31.4, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'price': '12.52460', 'display_qty': None, 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Added LimitOrder(SELL 31.4 APTUSDT-PERP.BINANCE LIMIT @ 12.52460 GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-17, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=LimitOrder(SELL 31.4 APTUSDT-PERP.BINANCE LIMIT @ 12.52460 GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-17, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT']), position_id=None)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-17, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=0.34076059 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=83.27692351 USDT, locked=1.29585156 USDT, free=81.98107195 USDT)], margins=[MarginBalance(initial=0.34076059 USDT, maintenance=0.95509097 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=467c8c17-f0aa-4637-8886-01e8935bf35a)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, venue_order_id=BINANCE-1-013, account_id=BINANCE-001, trade_id=BINANCE-1-014, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=468.6, last_px=11.92830 USDT, commission=2.79480069 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-15, venue_order_id=BINANCE-1-013, account_id=BINANCE-001, trade_id=BINANCE-1-014, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=468.6, last_px=11.92830 USDT, commission=2.79480069 USDT, liquidity_side=TAKER, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=500.0
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.20858250 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-15, closing_order_id=None, entry=BUY, side=LONG, signed_qty=500.0, quantity=500.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92829372, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-2.98207343 USDT, unrealized_pnl=0.00314000 USDT, ts_opened=1733788810101000000, ts_last=1733788810101000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-16') with VenueOrderId('BINANCE-1-014')
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=2.15543504 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=83.27692351 USDT, locked=17.36401754 USDT, free=65.91290597 USDT)], margins=[MarginBalance(initial=2.15543504 USDT, maintenance=15.20858250 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=3b05a76d-9067-4ac6-a8c1-197cee773dec)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-16, venue_order_id=BINANCE-1-014, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-16, venue_order_id=BINANCE-1-014, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: After stop loss order accepted balances locked: 17.36401754
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-17') with VenueOrderId('BINANCE-1-015')
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=4.16112448 USDT
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=83.27692351 USDT, locked=19.36970698 USDT, free=63.90721653 USDT)], margins=[MarginBalance(initial=4.16112448 USDT, maintenance=15.20858250 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=27fcbfe4-f111-4090-ae52-efaeaea80624)
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-17, venue_order_id=BINANCE-1-015, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-17, venue_order_id=BINANCE-1-015, account_id=BINANCE-001, ts_event=1733788810101000000)
# 2024-12-10T00:00:10.101000000Z [INFO] BACKTESTER-001.MACDStrategy: After take profit order accepted balances locked: 19.36970698
# 2024-12-10T00:00:10.101000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92660,14.3,SELLER,245141324,1733788810101000000)
# 2024-12-10T00:00:10.102000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92630,11.7,SELLER,245141325,1733788810102000000)
# 2024-12-10T00:00:10.103000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92600,37.5,SELLER,245141326,1733788810103000000)
# 2024-12-10T00:00:10.103000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92550,1.4,SELLER,245141327,1733788810103000000)
# 2024-12-10T00:00:10.103000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92540,39.0,SELLER,245141328,1733788810103000000)
# 2024-12-10T00:00:10.103000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92400,93.0,SELLER,245141329,1733788810103000000)
# 2024-12-10T00:00:10.109000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92160,23.9,SELLER,245141330,1733788810109000000)
# 2024-12-10T00:00:10.109000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92090,23.9,SELLER,245141331,1733788810109000000)
# 2024-12-10T00:00:10.113000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92050,4.5,BUYER,245141332,1733788810113000000)
# 2024-12-10T00:00:10.113000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92060,4.9,BUYER,245141333,1733788810113000000)
# ...
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-18, account_id=BINANCE-001, ts_event=1733788810163000000)
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=83.0 @ 11.92070, ask=83.0 @ 11.92070, last=11.92070
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-18, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=Position(LONG 500.0 APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000), fills=[(Price(11.92070), Quantity(83.0))]
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-18') with VenueOrderId('BINANCE-1-016')
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-0.63027876, USDT)]
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=4.16112448 USDT
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=82.15193570 USDT, locked=19.36970698 USDT, free=62.78222872 USDT)], margins=[MarginBalance(initial=4.16112448 USDT, maintenance=15.20858250 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=038b22ed-fbc7-46bf-a1f3-0751bd3c6cfb)
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-18, venue_order_id=BINANCE-1-016, account_id=BINANCE-001, trade_id=BINANCE-1-015, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=83.0, last_px=11.92070 USDT, commission=0.49470905 USDT, liquidity_side=TAKER, ts_event=1733788810163000000)
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-18, venue_order_id=BINANCE-1-016, account_id=BINANCE-001, trade_id=BINANCE-1-015, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=83.0, last_px=11.92070 USDT, commission=0.49470905 USDT, liquidity_side=TAKER, ts_event=1733788810163000000)
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=417.0
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=12.68395781 USDT
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-15, closing_order_id=None, entry=BUY, side=LONG, signed_qty=417.0, quantity=417.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92829372, avg_px_close=11.9207, realized_return=-0.00064, realized_pnl=-4.10706124 USDT, unrealized_pnl=-3.16658124 USDT, ts_opened=1733788810101000000, ts_last=1733788810163000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-3.20828124, USDT)]
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=4.16112448 USDT
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=76.45820936 USDT, locked=16.84508229 USDT, free=59.61312707 USDT)], margins=[MarginBalance(initial=4.16112448 USDT, maintenance=12.68395781 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=b3e5b07e-393b-42ec-a9f8-1a491c706b10)
# 2024-12-10T00:00:10.163000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-18, venue_order_id=BINANCE-1-016, account_id=BINANCE-001, trade_id=BINANCE-1-016, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=417.0, last_px=11.92060 USDT, commission=2.48544510 USDT, liquidity_side=TAKER, ts_event=1733788810163000000)
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-18, venue_order_id=BINANCE-1-016, account_id=BINANCE-001, trade_id=BINANCE-1-016, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=417.0, last_px=11.92060 USDT, commission=2.48544510 USDT, liquidity_side=TAKER, ts_event=1733788810163000000)
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=0
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.00000000 USDT
# 2024-12-10T00:00:10.163000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionClosed(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-15, closing_order_id=O-20241210-000010-001-000-18, entry=BUY, side=FLAT, signed_qty=0.0, quantity=0.0, peak_qty=500.0, currency=USDT, avg_px_open=11.92829372, avg_px_close=11.920616599999999, realized_return=-0.00064, realized_pnl=-9.80078758 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788810101000000, ts_last=1733788810163000000, ts_closed=1733788810163000000, duration_ns=62000000)
# 2024-12-10T00:00:10.170000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92040,21.9,SELLER,245141367,1733788810170000000)
# 2024-12-10T00:00:10.170000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92030,20.0,SELLER,245141368,1733788810170000000)
# 2024-12-10T00:00:10.174000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92100,2.4,BUYER,245141369,1733788810174000000)
# 2024-12-10T00:00:10.174000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92090,21.9,SELLER,245141370,1733788810174000000)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91930,16.8,SELLER,245141371,1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, side=SELL, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-19, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-19, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=16.8 @ 11.91930, ask=16.8 @ 11.91930, last=11.91930
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-19, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=None, fills=[(Price(11.91930), Quantity(16.8))]
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-19') with VenueOrderId('BINANCE-1-017')
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=4.16112448 USDT
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=76.35808724 USDT, locked=4.16112448 USDT, free=72.19696276 USDT)], margins=[MarginBalance(initial=4.16112448 USDT, maintenance=0.00000000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=90d35c53-3aa6-478a-9997-78d9596ff03a)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, venue_order_id=BINANCE-1-017, account_id=BINANCE-001, trade_id=BINANCE-1-017, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=16.8, last_px=11.91930 USDT, commission=0.10012212 USDT, liquidity_side=TAKER, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, venue_order_id=BINANCE-1-017, account_id=BINANCE-001, trade_id=BINANCE-1-017, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=16.8, last_px=11.91930 USDT, commission=0.10012212 USDT, liquidity_side=TAKER, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Snapshot Position(FLAT APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000-d9e05c80-c982-4fc4-9ac5-43817d0fca0d)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-16.8
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.51062281 USDT
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-19, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-16.8, quantity=16.8, peak_qty=16.8, currency=USDT, avg_px_open=11.9193, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.10012212 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788810181000000, ts_last=1733788810181000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-20, side=BUY, type=STOP_MARKET, quantity=16.8, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': '12.51530', 'trigger_type': 'LAST_PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['STOP'])
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Added StopMarketOrder(BUY 16.8 APTUSDT-PERP.BINANCE STOP_MARKET @ 12.51530[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-20, venue_order_id=None, position_id=None, tags=['STOP'])
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=StopMarketOrder(BUY 16.8 APTUSDT-PERP.BINANCE STOP_MARKET @ 12.51530[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-20, venue_order_id=None, position_id=None, tags=['STOP']), position_id=None)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-20, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-21, side=BUY, type=LIMIT, quantity=16.8, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'price': '11.32330', 'display_qty': None, 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Added LimitOrder(BUY 16.8 APTUSDT-PERP.BINANCE LIMIT @ 11.32330 GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-21, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=LimitOrder(BUY 16.8 APTUSDT-PERP.BINANCE LIMIT @ 11.32330 GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-21, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT']), position_id=None)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-21, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=4.16112448 USDT
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=73.47840852 USDT, locked=4.67174729 USDT, free=68.80666123 USDT)], margins=[MarginBalance(initial=4.16112448 USDT, maintenance=0.51062281 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=1e66d140-acab-4bc5-9051-9542cddd96af)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, venue_order_id=BINANCE-1-017, account_id=BINANCE-001, trade_id=BINANCE-1-018, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=483.2, last_px=11.91920 USDT, commission=2.87967872 USDT, liquidity_side=TAKER, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-19, venue_order_id=BINANCE-1-017, account_id=BINANCE-001, trade_id=BINANCE-1-018, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=483.2, last_px=11.91920 USDT, commission=2.87967872 USDT, liquidity_side=TAKER, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-500.0
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.19698000 USDT
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-19, closing_order_id=None, entry=SELL, side=SHOR

# %%
engine.trader.generate_account_report(Venue("BINANCE"))
# Out:
# T, signed_qty=-500.0, quantity=500.0, peak_qty=500.0, currency=USDT, avg_px_open=11.91920336, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-2.97980084 USDT, unrealized_pnl=0.00168000 USDT, ts_opened=1733788810181000000, ts_last=1733788810181000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-20') with VenueOrderId('BINANCE-1-018')
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=5.23343538 USDT
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=73.47840852 USDT, locked=20.43041538 USDT, free=53.04799314 USDT)], margins=[MarginBalance(initial=5.23343538 USDT, maintenance=15.19698000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=b04880da-e41b-4919-80b7-e7424b0e554a)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-20, venue_order_id=BINANCE-1-018, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-20, venue_order_id=BINANCE-1-018, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: After stop loss order accepted balances locked: 20.43041538
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-21') with VenueOrderId('BINANCE-1-019')
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=6.20361572 USDT
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=73.47840852 USDT, locked=21.40059572 USDT, free=52.07781280 USDT)], margins=[MarginBalance(initial=6.20361572 USDT, maintenance=15.19698000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=e80f5b19-c331-4f04-a4df-3998adad9d17)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-21, venue_order_id=BINANCE-1-019, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-21, venue_order_id=BINANCE-1-019, account_id=BINANCE-001, ts_event=1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [INFO] BACKTESTER-001.MACDStrategy: After take profit order accepted balances locked: 21.40059572
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.91920,25.0,SELLER,245141372,1733788810181000000)
# 2024-12-10T00:00:10.181000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92040,107.3,BUYER,245141373,1733788810181000000)
# 2024-12-10T00:00:10.196000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92060,87.5,BUYER,245141374,1733788810196000000)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92010,9.3,BUYER,245141375,1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92130,21.6,BUYER,245141376,1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92140,41.8,BUYER,245141377,1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92150,41.9,BUYER,245141378,1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-22, side=BUY, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-22, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Cache: Indexed PositionId('APTUSDT-PERP.BINANCE-MACDStrategy-000'), client_order_id=O-20241210-000010-001-000-22, strategy_id=MACDStrategy-000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-22, venue_order_id=None, position_id=None, tags=None), position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-22, account_id=BINANCE-001, ts_event=1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=41.9 @ 11.92150, ask=41.9 @ 11.92150, last=11.92150
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-22, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=Position(SHORT 500.0 APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000), fills=[(Price(11.92150), Quantity(41.9))]
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-22') with VenueOrderId('BINANCE-1-020')
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-0.09622922, USDT)]
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=6.20361572 USDT
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=73.13242387 USDT, locked=21.40059572 USDT, free=51.73182815 USDT)], margins=[MarginBalance(initial=6.20361572 USDT, maintenance=15.19698000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=70a6d657-a0b8-4441-b265-b85d2431895d)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-22, venue_order_id=BINANCE-1-020, account_id=BINANCE-001, trade_id=BINANCE-1-019, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=41.9, last_px=11.92150 USDT, commission=0.24975543 USDT, liquidity_side=TAKER, ts_event=1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-22, venue_order_id=BINANCE-1-020, account_id=BINANCE-001, trade_id=BINANCE-1-019, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=41.9, last_px=11.92150 USDT, commission=0.24975543 USDT, liquidity_side=TAKER, ts_event=1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=-458.1
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=13.92347308 USDT
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-19, closing_order_id=None, entry=SELL, side=SHORT, signed_qty=-458.1, quantity=458.1, peak_qty=500.0, currency=USDT, avg_px_open=11.91920336, avg_px_close=11.9215, realized_return=-0.00019, realized_pnl=-3.32578549 USDT, unrealized_pnl=-1.05209078 USDT, ts_opened=1733788810181000000, ts_last=1733788810201000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-1.09790078, USDT)]
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=6.20361572 USDT
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=69.30388061 USDT, locked=20.12708880 USDT, free=49.17679181 USDT)], margins=[MarginBalance(initial=6.20361572 USDT, maintenance=13.92347308 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=dede81ce-f711-433d-8f07-d76a5e335a26)
# 2024-12-10T00:00:10.201000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-22, venue_order_id=BINANCE-1-020, account_id=BINANCE-001, trade_id=BINANCE-1-020, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=458.1, last_px=11.92160 USDT, commission=2.73064248 USDT, liquidity_side=TAKER, ts_event=1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-22, venue_order_id=BINANCE-1-020, account_id=BINANCE-001, trade_id=BINANCE-1-020, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=458.1, last_px=11.92160 USDT, commission=2.73064248 USDT, liquidity_side=TAKER, ts_event=1733788810201000000)
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=0
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.00000000 USDT
# 2024-12-10T00:00:10.201000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionClosed(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-19, closing_order_id=O-20241210-000010-001-000-22, entry=SELL, side=FLAT, signed_qty=0.0, quantity=0.0, peak_qty=500.0, currency=USDT, avg_px_open=11.91920336, avg_px_close=11.92159162, realized_return=-0.00020, realized_pnl=-7.15432875 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788810181000000, ts_last=1733788810201000000, ts_closed=1733788810201000000, duration_ns=20000000)
# 2024-12-10T00:00:10.206000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92160,20.9,BUYER,245141379,1733788810206000000)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92160,16.2,SELLER,245141380,1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-23, side=BUY, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=False, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-23, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-23, venue_order_id=None, position_id=None, tags=None), position_id=None)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-23, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=16.2 @ 11.92160, ask=16.2 @ 11.92160, last=11.92160
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(BUY 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-23, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=None, fills=[(Price(11.92160), Quantity(16.2))]
# 2024-12-10T00:00
#                                          total       locked          free  \
# 2024-12-10 00:00:04.998000+00:00  100.00000000         0E-8  100.00000000
# 2024-12-10 00:00:05.048000+00:00   99.99403215         0E-8   99.99403215
# 2024-12-10 00:00:05.048000+00:00   97.01609995   0.03043604   96.98566391
# 2024-12-10 00:00:05.048000+00:00   97.01609995  15.28180575   81.73429420
# 2024-12-10 00:00:05.048000+00:00   97.01609995  15.33963414   81.67646581
# ...                                        ...          ...           ...
# 2024-12-10 00:00:11.884000+00:00   40.89897648  35.04000136    5.85897512
# 2024-12-10 00:00:12.479000+00:00   40.89172430  35.04000136    5.85172294
# 2024-12-10 00:00:12.479000+00:00   36.82005652  35.01265139    1.80740513
# 2024-12-10 00:00:12.482000+00:00   36.81469270  19.84557136   16.96912134
# 2024-12-10 00:00:12.482000+00:00   33.84013156  19.87292684   13.96720472
#
#                                  currency   account_id account_type  \
# 2024-12-10 00:00:04.998000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:05.048000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:05.048000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:05.048000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:05.048000+00:00     USDT  BINANCE-001       MARGIN
# ...                                   ...          ...          ...
# 2024-12-10 00:00:11.884000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:12.479000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:12.479000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:12.482000+00:00     USDT  BINANCE-001       MARGIN
# 2024-12-10 00:00:12.482000+00:00     USDT  BINANCE-001       MARGIN
#
#                                  base_currency  \
# 2024-12-10 00:00:04.998000+00:00          USDT
# 2024-12-10 00:00:05.048000+00:00          USDT
# 2024-12-10 00:00:05.048000+00:00          USDT
# 2024-12-10 00:00:05.048000+00:00          USDT
# 2024-12-10 00:00:05.048000+00:00          USDT
# ...                                        ...
# 2024-12-10 00:00:11.884000+00:00          USDT
# 2024-12-10 00:00:12.479000+00:00          USDT
# 2024-12-10 00:00:12.479000+00:00          USDT
# 2024-12-10 00:00:12.482000+00:00          USDT
# 2024-12-10 00:00:12.482000+00:00          USDT
#
#                                                                             margins  \
# 2024-12-10 00:00:04.998000+00:00                                                 []
# 2024-12-10 00:00:05.048000+00:00                                                 []
# 2024-12-10 00:00:05.048000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# 2024-12-10 00:00:05.048000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# 2024-12-10 00:00:05.048000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# ...                                                                             ...
# 2024-12-10 00:00:11.884000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# 2024-12-10 00:00:12.479000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# 2024-12-10 00:00:12.479000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# 2024-12-10 00:00:12.482000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
# 2024-12-10 00:00:12.482000+00:00  [{'type': 'MarginBalance', 'initial': '19.8971...
#
#                                   reported info
# 2024-12-10 00:00:04.998000+00:00      True   {}
# 2024-12-10 00:00:05.048000+00:00     False   {}
# 2024-12-10 00:00:05.048000+00:00     False   {}
# 2024-12-10 00:00:05.048000+00:00     False   {}
# 2024-12-10 00:00:05.048000+00:00     False   {}
# ...                                    ...  ...
# 2024-12-10 00:00:11.884000+00:00     False   {}
# 2024-12-10 00:00:12.479000+00:00     False   {}
# 2024-12-10 00:00:12.479000+00:00     False   {}
# 2024-12-10 00:00:12.482000+00:00     False   {}
# 2024-12-10 00:00:12.482000+00:00     False   {}
#
# [63 rows x 10 columns]
# :10.242000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-23') with VenueOrderId('BINANCE-1-021')
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=6.20361572 USDT
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=69.20731565 USDT, locked=6.20361572 USDT, free=63.00369993 USDT)], margins=[MarginBalance(initial=6.20361572 USDT, maintenance=0.00000000 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=60b97d8c-2cef-40bc-a084-7b5a4c309f59)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-23, venue_order_id=BINANCE-1-021, account_id=BINANCE-001, trade_id=BINANCE-1-021, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=16.2, last_px=11.92160 USDT, commission=0.09656496 USDT, liquidity_side=TAKER, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-23, venue_order_id=BINANCE-1-021, account_id=BINANCE-001, trade_id=BINANCE-1-021, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=16.2, last_px=11.92160 USDT, commission=0.09656496 USDT, liquidity_side=TAKER, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Cache: Snapshot Position(FLAT APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000-5b3b56f7-4288-493b-9c33-d2fd8d6c9a2e)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=16.2
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=0.49248130 USDT
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionOpened(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-23, closing_order_id=None, entry=BUY, side=LONG, signed_qty=16.2, quantity=16.2, peak_qty=16.2, currency=USDT, avg_px_open=11.9216, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-0.09656496 USDT, unrealized_pnl=0.00000000 USDT, ts_opened=1733788810242000000, ts_last=1733788810242000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-24, side=SELL, type=STOP_MARKET, quantity=16.2, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'trigger_price': '11.32550', 'trigger_type': 'LAST_PRICE', 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['STOP'])
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Cache: Added StopMarketOrder(SELL 16.2 APTUSDT-PERP.BINANCE STOP_MARKET @ 11.32550[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-24, venue_order_id=None, position_id=None, tags=['STOP'])
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=StopMarketOrder(SELL 16.2 APTUSDT-PERP.BINANCE STOP_MARKET @ 11.32550[LAST_PRICE] GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-24, venue_order_id=None, position_id=None, tags=['STOP']), position_id=None)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-24, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-25, side=SELL, type=LIMIT, quantity=16.2, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={'price': '12.51770', 'display_qty': None, 'expire_time_ns': 0}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Cache: Added LimitOrder(SELL 16.2 APTUSDT-PERP.BINANCE LIMIT @ 12.51770 GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-25, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT'])
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=LimitOrder(SELL 16.2 APTUSDT-PERP.BINANCE LIMIT @ 12.51770 GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-25, venue_order_id=None, position_id=None, tags=['TAKE_PROFIT']), position_id=None)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-25, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: []
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=6.20361572 USDT
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=66.32345642 USDT, locked=6.69609702 USDT, free=59.62735940 USDT)], margins=[MarginBalance(initial=6.20361572 USDT, maintenance=0.49248130 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=ceb69577-85ea-4e34-b69d-be989b654b26)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-23, venue_order_id=BINANCE-1-021, account_id=BINANCE-001, trade_id=BINANCE-1-022, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=483.8, last_px=11.92170 USDT, commission=2.88385923 USDT, liquidity_side=TAKER, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-23, venue_order_id=BINANCE-1-021, account_id=BINANCE-001, trade_id=BINANCE-1-022, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=BUY, order_type=MARKET, last_qty=483.8, last_px=11.92170 USDT, commission=2.88385923 USDT, liquidity_side=TAKER, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=500.0
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=15.20016750 USDT
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-23, closing_order_id=None, entry=BUY, side=LONG, signed_qty=500.0, quantity=500.0, peak_qty=500.0, currency=USDT, avg_px_open=11.921696760000001, avg_px_close=0.0, realized_return=0.00000, realized_pnl=-2.98042419 USDT, unrealized_pnl=0.00162000 USDT, ts_opened=1733788810242000000, ts_last=1733788810242000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-24') with VenueOrderId('BINANCE-1-022')
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=7.13932853 USDT
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=66.32345642 USDT, locked=22.33949603 USDT, free=43.98396039 USDT)], margins=[MarginBalance(initial=7.13932853 USDT, maintenance=15.20016750 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=0c74a351-cdec-4739-9c1c-b6b423b626da)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-24, venue_order_id=BINANCE-1-022, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-24, venue_order_id=BINANCE-1-022, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: After stop loss order accepted balances locked: 22.33949603
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-25') with VenueOrderId('BINANCE-1-023')
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=8.17354090 USDT
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=66.32345642 USDT, locked=23.37370840 USDT, free=42.94974802 USDT)], margins=[MarginBalance(initial=8.17354090 USDT, maintenance=15.20016750 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=d7aeb536-a3ed-404c-bcf8-67043dd97497)
# 2024-12-10T00:00:10.242000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-25, venue_order_id=BINANCE-1-023, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderAccepted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-25, venue_order_id=BINANCE-1-023, account_id=BINANCE-001, ts_event=1733788810242000000)
# 2024-12-10T00:00:10.242000000Z [INFO] BACKTESTER-001.MACDStrategy: After take profit order accepted balances locked: 23.3737084
# 2024-12-10T00:00:10.248000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92200,8.2,SELLER,245141381,1733788810248000000)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92100,25.0,SELLER,245141382,1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92090,112.7,SELLER,245141383,1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92020,0.9,SELLER,245141384,1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Processing TradeTick(APTUSDT-PERP.BINANCE,11.92000,28.5,SELLER,245141385,1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderInitialized(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-26, side=SELL, type=MARKET, quantity=500.0, time_in_force=GTC, post_only=False, reduce_only=True, quote_quantity=False, options={}, emulation_trigger=NO_TRIGGER, trigger_instrument_id=None, contingency_type=NO_CONTINGENCY, order_list_id=None, linked_order_ids=None, parent_order_id=None, exec_algorithm_id=None, exec_algorithm_params=None, exec_spawn_id=None, tags=None)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Cache: Added MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-26, venue_order_id=None, position_id=None, tags=None)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Cache: Indexed PositionId('APTUSDT-PERP.BINANCE-MACDStrategy-000'), client_order_id=O-20241210-000010-001-000-26, strategy_id=MACDStrategy-000)
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.MACDStrategy: [CMD]--> SubmitOrder(order=MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=INITIALIZED, client_order_id=O-20241210-000010-001-000-26, venue_order_id=None, position_id=None, tags=None), position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000)
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderSubmitted(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-26, account_id=BINANCE-001, ts_event=1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Market: bid=28.5 @ 11.92000, ask=28.5 @ 11.92000, last=11.92000
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.OrderMatchingEngine(BINANCE): Applying fills to MarketOrder(SELL 500.0 APTUSDT-PERP.BINANCE MARKET GTC, status=SUBMITTED, client_order_id=O-20241210-000010-001-000-26, venue_order_id=None, position_id=None, tags=None), venue_position_id=None, position=Position(LONG 500.0 APTUSDT-PERP.BINANCE, id=APTUSDT-PERP.BINANCE-MACDStrategy-000), fills=[(Price(11.92000), Quantity(28.5))]
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Cache: Indexed ClientOrderId('O-20241210-000010-001-000-26') with VenueOrderId('BINANCE-1-024')
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-0.04835766, USDT)]
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=8.17354090 USDT
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=66.10523876 USDT, locked=23.37370840 USDT, free=42.73153036 USDT)], margins=[MarginBalance(initial=8.17354090 USDT, maintenance=15.20016750 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=8b820017-5e59-41a1-aa39-8f8df47ca45f)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-26, venue_order_id=BINANCE-1-024, account_id=BINANCE-001, trade_id=BINANCE-1-023, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=28.5, last_px=11.92000 USDT, commission=0.16986000 USDT, liquidity_side=TAKER, ts_event=1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-26, venue_order_id=BINANCE-1-024, account_id=BINANCE-001, trade_id=BINANCE-1-023, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=28.5, last_px=11.92000 USDT, commission=0.16986000 USDT, liquidity_side=TAKER, ts_event=1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE net_position=471.5
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_maint=14.33375795 USDT
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] PositionChanged(instrument_id=APTUSDT-PERP.BINANCE, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, account_id=BINANCE-001, opening_order_id=O-20241210-000010-001-000-23, closing_order_id=None, entry=BUY, side=LONG, signed_qty=471.5, quantity=471.5, peak_qty=500.0, currency=USDT, avg_px_open=11.921696760000001, avg_px_close=11.92, realized_return=-0.00014, realized_pnl=-3.19864185 USDT, unrealized_pnl=-0.80002234 USDT, ts_opened=1733788810242000000, ts_last=1733788810265000000, ts_closed=0, duration_ns=0)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Portfolio: Calculated PnLs: [Money(-0.84717234, USDT)]
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.Portfolio: APTUSDT-PERP.BINANCE margin_init=8.17354090 USDT
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.Portfolio: Updated AccountState(account_id=BINANCE-001, account_type=MARGIN, base_currency=USDT, is_reported=False, balances=[AccountBalance(total=62.44794999 USDT, locked=22.50729885 USDT, free=39.94065114 USDT)], margins=[MarginBalance(initial=8.17354090 USDT, maintenance=14.33375795 USDT, instrument_id=APTUSDT-PERP.BINANCE)], event_id=d4fbcde1-3d84-40c1-ad48-b4953e9bb223)
# 2024-12-10T00:00:10.265000000Z [DEBUG] BACKTESTER-001.Portfolio: Updated OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order_id=O-20241210-000010-001-000-26, venue_order_id=BINANCE-1-024, account_id=BINANCE-001, trade_id=BINANCE-1-024, position_id=APTUSDT-PERP.BINANCE-MACDStrategy-000, order_side=SELL, order_type=MARKET, last_qty=471.5, last_px=11.91990 USDT, commission=2.81011643 USDT, liquidity_side=TAKER, ts_event=1733788810265000000)
# 2024-12-10T00:00:10.265000000Z [INFO] BACKTESTER-001.MACDStrategy: <--[EVT] OrderFilled(instrument_id=APTUSDT-PERP.BINANCE, client_order
